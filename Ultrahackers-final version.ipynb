# %% [markdown]
# # Data Cleaning

# %% [markdown]
# First we imported the data using pandas. We noticed that the data is missing headers so we added labels for each column.

# %%
import pandas as pd
import numpy as np

numOfHeaders = 29

#set the labels for the features
headers = ["feature "+str(i) for i in range(1,numOfHeaders)]

# mark the first column to be the target
headers = ["output"] + headers

#import the data and set the columns' headers to the labels
data = pd.read_csv("HIGGS_train.csv",names = headers, low_memory=False)
data
# Out:
#         output  feature 1  feature 2  feature 3  feature 4  feature 5  \
# 0          1.0      0.869     -0.635      0.226      0.327     -0.690
# 1          1.0      0.908      0.329      0.359      1.500     -0.313
# 2          1.0      0.799      1.470     -1.640      0.454      0.426
# 3          0.0      1.340     -0.877      0.936      1.990      0.882
# 4          1.0      1.110      0.321      1.520      0.883     -1.210
# ...        ...        ...        ...        ...        ...        ...
# 599995     0.0      0.680      0.223     -0.757      0.418     -0.323
# 599996     1.0      1.610     -1.620      0.212      0.716     -0.906
# 599997     1.0      1.070      0.364      0.344      0.617     -1.430
# 599998     1.0      1.180     -0.173     -1.460      0.735     -0.753
# 599999     0.0      0.771     -0.133     -1.020      1.790     -1.650
#
#         feature 6  feature 7  feature 8  feature 9  ...  feature 19  \
# ...

# %% [markdown]
# We noticed that there are some duplicated rows that we dropped down.

# %%
numOfDuplicatedRows = len(np.where(data.duplicated() == True)[0])
print("The number of duplicated rows = ",numOfDuplicatedRows)

data = data.drop_duplicates()
data
# Out:
# The number of duplicated rows =  802
#         output  feature 1  feature 2  feature 3  feature 4  feature 5  \
# 0          1.0      0.869     -0.635      0.226      0.327     -0.690
# 1          1.0      0.908      0.329      0.359      1.500     -0.313
# 2          1.0      0.799      1.470     -1.640      0.454      0.426
# 3          0.0      1.340     -0.877      0.936      1.990      0.882
# 4          1.0      1.110      0.321      1.520      0.883     -1.210
# ...        ...        ...        ...        ...        ...        ...
# 599995     0.0      0.680      0.223     -0.757      0.418     -0.323
# 599996     1.0      1.610     -1.620      0.212      0.716     -0.906
# 599997     1.0      1.070      0.364      0.344      0.617     -1.430
# 599998     1.0      1.180     -0.173     -1.460      0.735     -0.753
# 599999     0.0      0.771     -0.133     -1.020      1.790     -1.650
#
#         feature 6  feature 7  feature 8  feature 9  ...  feature 19  \
# ...

# %% [markdown]
# We searched for rows with missing data, and we got their indices and dropped them accordingly.

# %%
print("The number of rows that have null values is : ", len(np.where(data.isna().any(axis=1) == True)[0]))
#get the row with the missing data
rows = data[data.isna().any(axis=1)]
#get the index of that row and drop it
data = data.drop(rows.index,axis=0)
data
# Out:
# The number of rows that have null values is :  1
#         output  feature 1  feature 2  feature 3  feature 4  feature 5  \
# 0          1.0      0.869     -0.635      0.226      0.327     -0.690
# 1          1.0      0.908      0.329      0.359      1.500     -0.313
# 2          1.0      0.799      1.470     -1.640      0.454      0.426
# 3          0.0      1.340     -0.877      0.936      1.990      0.882
# 4          1.0      1.110      0.321      1.520      0.883     -1.210
# ...        ...        ...        ...        ...        ...        ...
# 599995     0.0      0.680      0.223     -0.757      0.418     -0.323
# 599996     1.0      1.610     -1.620      0.212      0.716     -0.906
# 599997     1.0      1.070      0.364      0.344      0.617     -1.430
# 599998     1.0      1.180     -0.173     -1.460      0.735     -0.753
# 599999     0.0      0.771     -0.133     -1.020      1.790     -1.650
#
#         feature 6  feature 7  feature 8  feature 9  ...  feature 19  \
# ...

# %% [markdown]
# We noticed that the data is not of the same type. We got the indices of the columns and the rows where the data is of type string. we looped over the cells with string data and converted them to float if applicable. if not, we replaced them with the mode of the column.

# %%
print("Is the data of the same type?",data.dtypes.nunique() == 1)
#get the indices of the columns that have non float values 
cols = np.where(data.dtypes != "float64")
#get the headers of those rows
cols = np.array([headers[i] for i in cols[0]])
#create a copy of the data
copyOfData = data
#convert everything to numeric type, if a data cell is non numeric, it will be converted to nan
copyOfData = copyOfData.apply(pd.to_numeric,errors='coerce')
#indices of the rows that contains non numeric values 
indices = np.where(copyOfData.isna().any(axis = 1))[0]

#loop over the rows
for row in indices:
    #loop over the elements of the row
    for col in cols:
        #get the element at that row at that col
        num = data.iloc[row][col]
        try: 
            #if applicable, get the numeric value of the string
            data = data.replace({col:{num:float(num.strip('"'))}})
        except:
            #replace the field with the mode
            data = data.replace({col:{num:data[col].mode()[0]}}) 
data
# Out:
# Is the data of the same type? False
#         output  feature 1  feature 2  feature 3  feature 4  feature 5  \
# 0          1.0      0.869     -0.635      0.226      0.327     -0.690
# 1          1.0      0.908      0.329      0.359      1.500     -0.313
# 2          1.0      0.799      1.470     -1.640      0.454      0.426
# 3          0.0      1.340     -0.877      0.936      1.990      0.882
# 4          1.0      1.110      0.321      1.520      0.883     -1.210
# ...        ...        ...        ...        ...        ...        ...
# 599995     0.0      0.680      0.223     -0.757      0.418     -0.323
# 599996     1.0      1.610     -1.620      0.212      0.716     -0.906
# 599997     1.0      1.070      0.364      0.344      0.617     -1.430
# 599998     1.0      1.180     -0.173     -1.460      0.735     -0.753
# 599999     0.0      0.771     -0.133     -1.020      1.790     -1.650
#
#         feature 6  feature 7  feature 8  feature 9  ...  feature 19  \
# ...

# %% [markdown]
# Checking if the data is skewed or not.
# The difference between the percentage of the number of positive and negative samples is acceptable

# %%
total_num = len(np.where(data["output"] == 1)[0]) + len(np.where(data["output"] == 0)[0])
positive_samples = len(np.where(data["output"] == 1)[0]) / q  #0.529994309050279
negative_sampels = len(np.where(data["output"] == 0)[0]) / q  #0.47000569094972106

# %% [markdown]
# # Data Training:

# %% [markdown]
# # 1) Training the data with the logistic regression model:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

y = np.array(data.iloc[:,0])
X = np.array(data.iloc[:,1:])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model= LogisticRegression()
model.fit(X_train, y_train)
print("The accuracy of the logistic regression model = ",model.score(X_test,y_test))
# Out:
# The accuracy of the logistic regression model =  0.6433995327102804

# %% [markdown]
# # 2) Training the data with the xgboost classifier:

# %%
# 0.740762
#add max features attribute
from xgboost import XGBClassifier

model = XGBClassifier(max_depth = 5, eta = 0.3, n_estimators= 290, min_child_weight= 10,subsample=0.9, colsample_bytree = 0.9 )
model.fit(X_train, y_train)
print("test accuracy ",model.score(X_test,y_test))
print("train accuracy ", model.score(X_train, y_train))
# Out:
# test accuracy  0.7407626835781042
# train accuracy  0.7634038931318412

# %%
from xgboost import XGBClassifier

model = XGBClassifier(max_depth = 5, n_estimators= 100, learning_rate = 0.5, max_features = 0.3, min_samples_leaf=200 )
model.fit(X_train, y_train)
print("test accuracy ",model.score(X_test,y_test))
print("train accuracy ", model.score(X_train, y_train))

# %%
"""
test accuracy  0.7319592790387183
train accuracy  0.7497939948722977
"""

# %% [markdown]
# # 3) Training the data with the neural networks from sklearn MLPClassifier

# %%
from sklearn.neural_network import MLPClassifier
#test accuracy  0.7489652870493992
mlp = MLPClassifier(hidden_layer_sizes=(28,25, 25, 20, 17,13,5,3), max_iter=300, activation='relu', learning_rate_init=0.001, verbose = True)
mlp.fit(X_train, y_train)
print("test accuracy ",mlp.score(X_test,y_test))
print("train accuracy ", mlp.score(X_train, y_train))
# Out:
# Iteration 1, loss = 0.62416247
# Iteration 2, loss = 0.58875025
# Iteration 3, loss = 0.57765061
# Iteration 4, loss = 0.57069185
# Iteration 5, loss = 0.56359142
# Iteration 6, loss = 0.55630466
# Iteration 7, loss = 0.55108926
# Iteration 8, loss = 0.54724181
# Iteration 9, loss = 0.54415115
# Iteration 10, loss = 0.54187449
# Iteration 11, loss = 0.53981676
# Iteration 12, loss = 0.53768371
# Iteration 13, loss = 0.53571305
# Iteration 14, loss = 0.53320374
# Iteration 15, loss = 0.53047800
# Iteration 16, loss = 0.52785472
# Iteration 17, loss = 0.52561152
# Iteration 18, loss = 0.52400897
# Iteration 19, loss = 0.52239559
# Iteration 20, loss = 0.52124058
# Iteration 21, loss = 0.52058396
# Iteration 22, loss = 0.51890402
# Iteration 23, loss = 0.51851948
# Iteration 24, loss = 0.51771555
# Iteration 25, loss = 0.51681072
# Iteration 26, loss = 0.51646809
# Iteration 27, loss = 0.51539841
# Iteration 28, loss = 0.51511607
# Iteration 29, loss = 0.51409185
# ...

# %%
#best model so far
#0.7501251668891856
mlp = MLPClassifier(hidden_layer_sizes=(80,60,40,20,5), max_iter=300, activation='relu', learning_rate_init=0.003, verbose = True)
mlp.fit(X_train, y_train)
print("test accuracy ",mlp.score(X_test,y_test))
print("train accuracy ", mlp.score(X_train, y_train))
# Out:
# Iteration 1, loss = 0.61550970
# Iteration 2, loss = 0.57559801
# Iteration 3, loss = 0.56173950
# Iteration 4, loss = 0.55302818
# Iteration 5, loss = 0.54567324
# Iteration 6, loss = 0.53950796
# Iteration 7, loss = 0.53463076
# Iteration 8, loss = 0.53075566
# Iteration 9, loss = 0.52712194
# Iteration 10, loss = 0.52414717
# Iteration 11, loss = 0.52180925
# Iteration 12, loss = 0.51992471
# Iteration 13, loss = 0.51738075
# Iteration 14, loss = 0.51603183
# Iteration 15, loss = 0.51450924
# Iteration 16, loss = 0.51382127
# Iteration 17, loss = 0.51246409
# Iteration 18, loss = 0.51159863
# Iteration 19, loss = 0.51010580
# Iteration 20, loss = 0.50960693
# Iteration 21, loss = 0.50820922
# Iteration 22, loss = 0.50769285
# Iteration 23, loss = 0.50734320
# Iteration 24, loss = 0.50649404
# Iteration 25, loss = 0.50612561
# Iteration 26, loss = 0.50521657
# Iteration 27, loss = 0.50457493
# Iteration 28, loss = 0.50423618
# Iteration 29, loss = 0.50348765
# ...

# %%
#0.7498831775700935
mlp = MLPClassifier(hidden_layer_sizes=(80,60,40,20,5), max_iter=300, activation='logistic', learning_rate_init=0.003, verbose = True)
mlp.fit(X_train, y_train)
print("test accuracy ",mlp.score(X_test,y_test))
print("train accuracy ", mlp.score(X_train, y_train))
# Out:
# Iteration 1, loss = 0.63674398
# Iteration 2, loss = 0.59654358
# Iteration 3, loss = 0.58776979
# Iteration 4, loss = 0.58209974
# Iteration 5, loss = 0.57702967
# Iteration 6, loss = 0.57213594
# Iteration 7, loss = 0.56724009
# Iteration 8, loss = 0.56188551
# Iteration 9, loss = 0.55726218
# Iteration 10, loss = 0.55322426
# Iteration 11, loss = 0.54991684
# Iteration 12, loss = 0.54654646
# Iteration 13, loss = 0.54366532
# Iteration 14, loss = 0.54109659
# Iteration 15, loss = 0.53791421
# Iteration 16, loss = 0.53571866
# Iteration 17, loss = 0.53374457
# Iteration 18, loss = 0.53179386
# Iteration 19, loss = 0.52963084
# Iteration 20, loss = 0.52815796
# Iteration 21, loss = 0.52577724
# Iteration 22, loss = 0.52416716
# Iteration 23, loss = 0.52222878
# Iteration 24, loss = 0.52082756
# Iteration 25, loss = 0.51935538
# Iteration 26, loss = 0.51748087
# Iteration 27, loss = 0.51626602
# Iteration 28, loss = 0.51492700
# Iteration 29, loss = 0.51371773
# ...

# %%
#0.7519526034712951
mlp = MLPClassifier(hidden_layer_sizes=(80,60,40,20,5), max_iter=300, activation='relu', solver ='adam' ,learning_rate_init=0.003, verbose = True)
mlp.fit(X_train, y_train)
print("test accuracy ",mlp.score(X_test,y_test))
print("train accuracy ", mlp.score(X_train, y_train))
# Out:
# Iteration 1, loss = 0.60735042
# Iteration 2, loss = 0.57416577
# Iteration 3, loss = 0.56064703
# Iteration 4, loss = 0.55081125
# Iteration 5, loss = 0.54414023
# Iteration 6, loss = 0.53931195
# Iteration 7, loss = 0.53508366
# Iteration 8, loss = 0.53155070
# Iteration 9, loss = 0.52800465
# Iteration 10, loss = 0.52522628
# Iteration 11, loss = 0.52297718
# Iteration 12, loss = 0.52056864
# Iteration 13, loss = 0.51874839
# Iteration 14, loss = 0.51726511
# Iteration 15, loss = 0.51601221
# Iteration 16, loss = 0.51459321
# Iteration 17, loss = 0.51362594
# Iteration 18, loss = 0.51244764
# Iteration 19, loss = 0.51149616
# Iteration 20, loss = 0.51009291
# Iteration 21, loss = 0.50957618
# Iteration 22, loss = 0.50908806
# Iteration 23, loss = 0.50798993
# Iteration 24, loss = 0.50706364
# Iteration 25, loss = 0.50641806
# Iteration 26, loss = 0.50591995
# Iteration 27, loss = 0.50553549
# Iteration 28, loss = 0.50522900
# Iteration 29, loss = 0.50463844
# ...

# %%
mlp = MLPClassifier(hidden_layer_sizes=(80,60,40,20,5), max_iter=300, activation='relu', solver ='adam' ,learning_rate_init=0.001, verbose = True)
mlp.fit(X_train, y_train)
print("test accuracy ",mlp.score(X_test,y_test))
print("train accuracy ", mlp.score(X_train, y_train))
# Out:
# Iteration 1, loss = 0.61749809
# Iteration 2, loss = 0.57986756
# Iteration 3, loss = 0.56595970
# Iteration 4, loss = 0.55525815
# Iteration 5, loss = 0.54800862
# Iteration 6, loss = 0.54196204
# Iteration 7, loss = 0.53727491
# Iteration 8, loss = 0.53337380
# Iteration 9, loss = 0.52969502
# Iteration 10, loss = 0.52652716
# Iteration 11, loss = 0.52385462
# Iteration 12, loss = 0.52163704
# Iteration 13, loss = 0.51895166
# Iteration 14, loss = 0.51678906
# Iteration 15, loss = 0.51495168
# Iteration 16, loss = 0.51315691
# Iteration 17, loss = 0.51183531
# Iteration 18, loss = 0.51056840
# Iteration 19, loss = 0.50883937
# Iteration 20, loss = 0.50791805
# Iteration 21, loss = 0.50669576
# Iteration 22, loss = 0.50622139
# Iteration 23, loss = 0.50483256
# Iteration 24, loss = 0.50391951
# Iteration 25, loss = 0.50319931
# Iteration 26, loss = 0.50252004
# Iteration 27, loss = 0.50190624
# Iteration 28, loss = 0.50057537
# Iteration 29, loss = 0.50065422
# ...

# %%
#test accuracy  0.7503755006675568
mlp = MLPClassifier(hidden_layer_sizes=(80,60,40,20,5), max_iter=600, activation='relu', solver ='adam' ,learning_rate_init=0.0003, verbose = True)
mlp.fit(X_train, y_train)
print("test accuracy ",mlp.score(X_test,y_test))
print("train accuracy ", mlp.score(X_train, y_train))
# Out:
# Iteration 1, loss = 0.62953158
# Iteration 2, loss = 0.59686609
# Iteration 3, loss = 0.58485018
# Iteration 4, loss = 0.57631243
# Iteration 5, loss = 0.56926661
# Iteration 6, loss = 0.56328451
# Iteration 7, loss = 0.55864543
# Iteration 8, loss = 0.55456205
# Iteration 9, loss = 0.55093825
# Iteration 10, loss = 0.54693145
# Iteration 11, loss = 0.54428633
# Iteration 12, loss = 0.54085801
# Iteration 13, loss = 0.53784963
# Iteration 14, loss = 0.53473271
# Iteration 15, loss = 0.53227588
# Iteration 16, loss = 0.53000234
# Iteration 17, loss = 0.52741914
# Iteration 18, loss = 0.52529387
# Iteration 19, loss = 0.52305883
# Iteration 20, loss = 0.52130585
# Iteration 21, loss = 0.51960701
# Iteration 22, loss = 0.51791477
# Iteration 23, loss = 0.51673035
# Iteration 24, loss = 0.51529165
# Iteration 25, loss = 0.51420859
# Iteration 26, loss = 0.51300628
# Iteration 27, loss = 0.51175206
# Iteration 28, loss = 0.51091791
# Iteration 29, loss = 0.51003854
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_5 = MLPClassifier(hidden_layer_sizes= np.array([100, 90, 40, 5, 1]), solver = 'adam', alpha= 0.008, verbose=True)
m_5.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_5.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_5.score(X_test, y_test))

# %%
"""
Output exceeds the size limit. Open the full output data in a text editorIteration 1, loss = 0.61753098
Iteration 2, loss = 0.58128748
Iteration 3, loss = 0.56510885
Iteration 4, loss = 0.55423165
Iteration 5, loss = 0.54700474
Iteration 6, loss = 0.54059656
Iteration 7, loss = 0.53586476
Iteration 8, loss = 0.53113776
Iteration 9, loss = 0.52707304
Iteration 10, loss = 0.52356394
Iteration 11, loss = 0.52112804
Iteration 12, loss = 0.51842094
Iteration 13, loss = 0.51613406
Iteration 14, loss = 0.51465654
Iteration 15, loss = 0.51246155
Iteration 16, loss = 0.51178334
Iteration 17, loss = 0.51096161
Iteration 18, loss = 0.50940339
Iteration 19, loss = 0.50848199
Iteration 20, loss = 0.50807287
Iteration 21, loss = 0.50672097
Iteration 22, loss = 0.50604898
Iteration 23, loss = 0.50528229
Iteration 24, loss = 0.50478331
Iteration 25, loss = 0.50423833
...
Iteration 153, loss = 0.48903922
Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
The training accuracy of the mlp classifier model =  0.7686838827846469
The testing accuracy of the mlp classifier model =  0.7506675567423231
"""

# %%
from sklearn.neural_network import MLPClassifier

m_8 = MLPClassifier(hidden_layer_sizes= np.array([100, 28, 58, 10, 1]), alpha = 0.01, verbose=True)
m_8.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_8.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_8.score(X_test, y_test))

# %%
"""
Output exceeds the size limit. Open the full output data in a text editorIteration 1, loss = 0.61739217
Iteration 2, loss = 0.58367387
Iteration 3, loss = 0.56888596
Iteration 4, loss = 0.55916353
Iteration 5, loss = 0.55198665
Iteration 6, loss = 0.54576708
Iteration 7, loss = 0.54137741
Iteration 8, loss = 0.53770991
Iteration 9, loss = 0.53487515
Iteration 10, loss = 0.53274147
Iteration 11, loss = 0.53109377
Iteration 12, loss = 0.52941908
Iteration 13, loss = 0.52742954
Iteration 14, loss = 0.52621018
Iteration 15, loss = 0.52411388
Iteration 16, loss = 0.52299591
Iteration 17, loss = 0.52161012
Iteration 18, loss = 0.52064745
Iteration 19, loss = 0.51927561
Iteration 20, loss = 0.51843772
Iteration 21, loss = 0.51711335
Iteration 22, loss = 0.51665579
Iteration 23, loss = 0.51540522
Iteration 24, loss = 0.51494222
Iteration 25, loss = 0.51372320
...
Iteration 126, loss = 0.49948064
Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
The training accuracy of the mlp classifier model =  0.7589270627110901
The testing accuracy of the mlp classifier model =  0.7517857142857143
"""

# %%
from sklearn.neural_network import MLPClassifier

m_11 = MLPClassifier(hidden_layer_sizes= np.array([99, 88, 77, 66, 55, 44, 33, 22, 11, 1]), verbose=True, shuffle=True, max_iter = 300)
m_11.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_11.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_11.score(X_test, y_test))

# %%
"""
Output exceeds the size limit. Open the full output data in a text editorIteration 1, loss = 0.61751397
Iteration 2, loss = 0.58063423
Iteration 3, loss = 0.56231896
Iteration 4, loss = 0.55113027
Iteration 5, loss = 0.54289163
Iteration 6, loss = 0.53620824
Iteration 7, loss = 0.53098345
Iteration 8, loss = 0.52632225
Iteration 9, loss = 0.52167762
Iteration 10, loss = 0.51836432
Iteration 11, loss = 0.51520249
Iteration 12, loss = 0.51219749
Iteration 13, loss = 0.50941622
Iteration 14, loss = 0.50681628
Iteration 15, loss = 0.50536667
Iteration 16, loss = 0.50289317
Iteration 17, loss = 0.50087542
Iteration 18, loss = 0.49958170
Iteration 19, loss = 0.49752282
Iteration 20, loss = 0.49630208
Iteration 21, loss = 0.49554410
Iteration 22, loss = 0.49389406
Iteration 23, loss = 0.49278222
Iteration 24, loss = 0.49242504
Iteration 25, loss = 0.49086132
...
Iteration 297, loss = 0.44168736
Iteration 298, loss = 0.44164962
Iteration 299, loss = 0.44181554
Iteration 300, loss = 0.44172526
/usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
  warnings.warn(
The training accuracy of the mlp classifier model =  0.7922341803707884
The testing accuracy of the mlp classifier model =  0.7415387182910548
"""

# %%
from sklearn.neural_network import MLPClassifier

m_19 = MLPClassifier(hidden_layer_sizes= np.array([28, 18, 8]), verbose=True, max_iter = 500)
m_19.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_19.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_19.score(X_test, y_test))

# %%
"""
Output exceeds the size limit. Open the full output data in a text editorIteration 1, loss = 0.61462449
Iteration 2, loss = 0.58219121
Iteration 3, loss = 0.56881285
Iteration 4, loss = 0.55874166
Iteration 5, loss = 0.55160371
Iteration 6, loss = 0.54634869
Iteration 7, loss = 0.54158632
Iteration 8, loss = 0.53769611
Iteration 9, loss = 0.53378626
Iteration 10, loss = 0.53045546
Iteration 11, loss = 0.52720881
Iteration 12, loss = 0.52416791
Iteration 13, loss = 0.52172638
Iteration 14, loss = 0.51934805
Iteration 15, loss = 0.51708012
Iteration 16, loss = 0.51622047
Iteration 17, loss = 0.51399747
Iteration 18, loss = 0.51235624
Iteration 19, loss = 0.51174276
Iteration 20, loss = 0.51020937
Iteration 21, loss = 0.50911870
Iteration 22, loss = 0.50802739
Iteration 23, loss = 0.50707612
Iteration 24, loss = 0.50612390
Iteration 25, loss = 0.50574718
...
Iteration 229, loss = 0.48342679
Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
The training accuracy of the mlp classifier model =  0.7635853862570068
The testing accuracy of the mlp classifier model =  0.7505674232309746
"""

# %%
from sklearn.neural_network import MLPClassifier

m_24 = MLPClassifier(hidden_layer_sizes= np.array([77, 53, 15, 6]), verbose=True, max_iter = 500)
m_24.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_24.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_24.score(X_test, y_test))

# %%
"""
Output exceeds the size limit. Open the full output data in a text editorIteration 1, loss = 0.61644596
Iteration 2, loss = 0.58538869
Iteration 3, loss = 0.57308455
Iteration 4, loss = 0.56290264
Iteration 5, loss = 0.55483027
Iteration 6, loss = 0.54879625
Iteration 7, loss = 0.54393814
Iteration 8, loss = 0.54008120
Iteration 9, loss = 0.53620336
Iteration 10, loss = 0.53264584
Iteration 11, loss = 0.52968635
Iteration 12, loss = 0.52642078
Iteration 13, loss = 0.52357229
Iteration 14, loss = 0.52146286
Iteration 15, loss = 0.51973151
Iteration 16, loss = 0.51795128
Iteration 17, loss = 0.51606779
Iteration 18, loss = 0.51505186
Iteration 19, loss = 0.51347665
Iteration 20, loss = 0.51245095
Iteration 21, loss = 0.51115917
Iteration 22, loss = 0.51027113
Iteration 23, loss = 0.50933763
Iteration 24, loss = 0.50817754
Iteration 25, loss = 0.50776656
...
Iteration 163, loss = 0.48380961
Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
The training accuracy of the mlp classifier model =  0.7620166180946559
The testing accuracy of the mlp classifier model =  0.7510931241655541
"""

# %%
m_31 = MLPClassifier(hidden_layer_sizes= np.array([250, 105, 90]), verbose=True, random_state = 0, early_stopping=True, alpha=0.1)
m_31.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_31.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_31.score(X_test, y_test))

# %%
"""
Iteration 1, loss = 0.63428396
Validation score: 0.677591
Iteration 2, loss = 0.59330322
Validation score: 0.701060
Iteration 3, loss = 0.58080416
Validation score: 0.705816
Iteration 4, loss = 0.57276407
Validation score: 0.710698
Iteration 5, loss = 0.56798164
Validation score: 0.709279
Iteration 6, loss = 0.56391243
Validation score: 0.719939
Iteration 7, loss = 0.56059519
Validation score: 0.721712
Iteration 8, loss = 0.55798159
Validation score: 0.718521
Iteration 9, loss = 0.55549434
Validation score: 0.730140
Iteration 10, loss = 0.55288263
Validation score: 0.729723
Iteration 11, loss = 0.55090814
Validation score: 0.727366
Iteration 12, loss = 0.54926330
Validation score: 0.726656
Iteration 13, loss = 0.54824881
Validation score: 0.728117
Iteration 14, loss = 0.54724503
Validation score: 0.733353
Iteration 15, loss = 0.54623948
Validation score: 0.732497
Iteration 16, loss = 0.54521734
Validation score: 0.731392
Iteration 17, loss = 0.54463762
Validation score: 0.731288
Iteration 18, loss = 0.54426202
Validation score: 0.735335
Iteration 19, loss = 0.54381019
Validation score: 0.733165
Iteration 20, loss = 0.54328763
Validation score: 0.740008
Iteration 21, loss = 0.54277857
Validation score: 0.737608
Iteration 22, loss = 0.54242626
Validation score: 0.733999
Iteration 23, loss = 0.54225478
Validation score: 0.738109
Iteration 24, loss = 0.54160492
Validation score: 0.729660
Iteration 25, loss = 0.54096505
Validation score: 0.737671
Iteration 26, loss = 0.54114299
Validation score: 0.736795
Iteration 27, loss = 0.54037513
Validation score: 0.732977
Iteration 28, loss = 0.54048900
Validation score: 0.737483
Iteration 29, loss = 0.53973151
Validation score: 0.735668
Iteration 30, loss = 0.53948559
Validation score: 0.741384
Iteration 31, loss = 0.53901069
Validation score: 0.739778
Iteration 32, loss = 0.53849608
Validation score: 0.742490
Iteration 33, loss = 0.53860535
Validation score: 0.742031
Iteration 34, loss = 0.53817221
Validation score: 0.739048
Iteration 35, loss = 0.53806447
Validation score: 0.735710
Iteration 36, loss = 0.53779638
Validation score: 0.741530
Iteration 37, loss = 0.53780515
Validation score: 0.739569
Iteration 38, loss = 0.53766900
Validation score: 0.734333
Iteration 39, loss = 0.53728800
Validation score: 0.735355
Iteration 40, loss = 0.53745497
Validation score: 0.740821
Iteration 41, loss = 0.53705251
Validation score: 0.736419
Iteration 42, loss = 0.53738593
Validation score: 0.742532
Iteration 43, loss = 0.53667417
Validation score: 0.742886
Iteration 44, loss = 0.53699396
Validation score: 0.737462
Iteration 45, loss = 0.53701873
Validation score: 0.739861
Iteration 46, loss = 0.53696638
Validation score: 0.742261
Iteration 47, loss = 0.53670873
Validation score: 0.739778
Iteration 48, loss = 0.53652056
Validation score: 0.742845
Iteration 49, loss = 0.53640804
Validation score: 0.741551
Iteration 50, loss = 0.53637993
Validation score: 0.741134
Iteration 51, loss = 0.53673130
Validation score: 0.739465
Iteration 52, loss = 0.53604554
Validation score: 0.742594
Iteration 53, loss = 0.53666617
Validation score: 0.741906
Iteration 54, loss = 0.53633166
Validation score: 0.740905
Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
The training accuracy of the mlp classifier model =  0.745940916686311
The testing accuracy of the mlp classifier model =  0.7395944592790387
"""

# %%
m_37 = MLPClassifier(hidden_layer_sizes= np.array([543, 205, 87]), verbose=True, random_state = 0, early_stopping=True, alpha=0.1, learning_rate_init=0.005)
m_37.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_37.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_37.score(X_test, y_test))

# %%
"""
Iteration 1, loss = 0.63041329
Validation score: 0.680032
Iteration 2, loss = 0.60247544
Validation score: 0.680595
Iteration 3, loss = 0.59410507
Validation score: 0.693571
Iteration 4, loss = 0.58713348
Validation score: 0.695386
Iteration 5, loss = 0.58297229
Validation score: 0.707840
Iteration 6, loss = 0.58061836
Validation score: 0.707735
Iteration 7, loss = 0.57920047
Validation score: 0.709050
Iteration 8, loss = 0.57762134
Validation score: 0.711261
Iteration 9, loss = 0.57728658
Validation score: 0.702833
Iteration 10, loss = 0.57729066
Validation score: 0.712846
Iteration 11, loss = 0.57634903
Validation score: 0.716852
Iteration 12, loss = 0.57633150
Validation score: 0.709133
Iteration 13, loss = 0.57605412
Validation score: 0.712325
Iteration 14, loss = 0.57562718
Validation score: 0.716351
Iteration 15, loss = 0.57481302
Validation score: 0.715579
Iteration 16, loss = 0.57388727
Validation score: 0.702332
Iteration 17, loss = 0.57344098
Validation score: 0.701039
Iteration 18, loss = 0.57394227
Validation score: 0.710698
Iteration 19, loss = 0.57266073
Validation score: 0.718291
Iteration 20, loss = 0.57233152
Validation score: 0.716247
Iteration 21, loss = 0.57294249
Validation score: 0.713868
Iteration 22, loss = 0.57253786
Validation score: 0.713472
Iteration 23, loss = 0.57225582
Validation score: 0.715809
Iteration 24, loss = 0.57275813
Validation score: 0.718708
Iteration 25, loss = 0.57288447
Validation score: 0.712867
Iteration 26, loss = 0.57198856
Validation score: 0.714912
Iteration 27, loss = 0.57216146
Validation score: 0.703271
Iteration 28, loss = 0.57263447
Validation score: 0.717394
Iteration 29, loss = 0.57219593
Validation score: 0.696616
Iteration 30, loss = 0.57275367
Validation score: 0.717102
Iteration 31, loss = 0.57235400
Validation score: 0.713222
Iteration 32, loss = 0.57168297
Validation score: 0.718583
Iteration 33, loss = 0.57220363
Validation score: 0.713702
Iteration 34, loss = 0.57173620
Validation score: 0.714432
Iteration 35, loss = 0.57180575
Validation score: 0.718729
Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
The training accuracy of the mlp classifier model =  0.7194616955630146
The testing accuracy of the mlp classifier model =  0.7174983311081442
"""

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=np.array([500,100,1]),activation="relu",max_iter=100)
model.fit(X_train,y_train)
print("The accuracy of the mlp calssifier model = ",model.score(X_test,y_test))

# %%
"""
The accuracy of the mlp calssifier model =  0.7276034712950601
"""

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=np.array([28,14,1]),activation="relu",max_iter=100)
model.fit(X_train,y_train)
print("The accuracy of the mlp calssifier model = ",model.score(X_test,y_test))

# %%
"""
The accuracy of the mlp calssifier model =  0.7339619492656876
"""

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=np.array([50,25,1]),activation="relu",max_iter=100)
model.fit(X_train,y_train)
print("The accuracy of the mlp calssifier model = ",model.score(X_test,y_test))

# %%
"""
The accuracy of the mlp calssifier model =  0.7394943257676903
"""

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=np.array([75,50,1]),activation="relu",max_iter=100)
model.fit(X_train,y_train)
print("The accuracy of the mlp calssifier model = ",model.score(X_test,y_test))

# %%
"""
The accuracy of the mlp calssifier model =  0.7447263017356476
"""

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=np.array([90,60,1]),activation="relu",max_iter=100)
model.fit(X_train,y_train)
print("The accuracy of the mlp calssifier model = ",model.score(X_test,y_test))

# %%
"""
The accuracy of the mlp calssifier model =  0.7476468624833111
"""

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=np.array([100,100,80,66,50,25,1]),activation="relu",verbose=True)
model.fit(X_train,y_train)
print("The training accuracy of the mlp calssifier model = ",model.score(X_train,y_train))
print("The testing accuracy of the mlp calssifier model = ",model.score(X_test,y_test))

# %%
"""
Output exceeds the size limit. Open the full output data in a text editorIteration 1, loss = 0.61228438
Iteration 2, loss = 0.57708157
Iteration 3, loss = 0.56031490
Iteration 4, loss = 0.54750591
Iteration 5, loss = 0.53795368
Iteration 6, loss = 0.53173331
Iteration 7, loss = 0.52597696
Iteration 8, loss = 0.52195401
Iteration 9, loss = 0.51733185
Iteration 10, loss = 0.51407010
Iteration 11, loss = 0.51073185
Iteration 12, loss = 0.50801457
Iteration 13, loss = 0.50579432
Iteration 14, loss = 0.50420168
Iteration 15, loss = 0.50163041
Iteration 16, loss = 0.50023704
Iteration 17, loss = 0.49850947
Iteration 18, loss = 0.49702998
Iteration 19, loss = 0.49593982
Iteration 20, loss = 0.49412677
Iteration 21, loss = 0.49352239
Iteration 22, loss = 0.49148949
Iteration 23, loss = 0.49098122
Iteration 24, loss = 0.49040358
Iteration 25, loss = 0.48918241
...
Iteration 197, loss = 0.44632814
Iteration 198, loss = 0.44630433
Iteration 199, loss = 0.44633442
Iteration 200, loss = 0.44617243
C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
  warnings.warn(
The training accuracy of the mlp calssifier model =  0.7887503468187593
The testing accuracy of the mlp calssifier model =  0.7431992656875834
"""

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=np.array([100,75,50,25,1]),activation="relu",verbose=True,max_iter=500)
model.fit(X_train,y_train)
print("The training accuracy of the mlp calssifier model = ",model.score(X_train,y_train))
print("The testing accuracy of the mlp calssifier model = ",model.score(X_test,y_test))

# %%
"""
Output exceeds the size limit. Open the full output data in a text editorIteration 1, loss = 0.61809784
Iteration 2, loss = 0.58158476
Iteration 3, loss = 0.56675706
Iteration 4, loss = 0.55618146
Iteration 5, loss = 0.54791767
Iteration 6, loss = 0.54106800
Iteration 7, loss = 0.53545248
Iteration 8, loss = 0.53063098
Iteration 9, loss = 0.52661386
Iteration 10, loss = 0.52309597
Iteration 11, loss = 0.51969085
Iteration 12, loss = 0.51718919
Iteration 13, loss = 0.51505516
Iteration 14, loss = 0.51238610
Iteration 15, loss = 0.51064211
Iteration 16, loss = 0.50876675
Iteration 17, loss = 0.50721743
Iteration 18, loss = 0.50567760
Iteration 19, loss = 0.50449329
Iteration 20, loss = 0.50290673
Iteration 21, loss = 0.50158206
Iteration 22, loss = 0.50062926
Iteration 23, loss = 0.49980201
Iteration 24, loss = 0.49915068
Iteration 25, loss = 0.49752688
...
Iteration 233, loss = 0.46457505
Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
The training accuracy of the mlp calssifier model =  0.7781048362702537
The testing accuracy of the mlp calssifier model =  0.748923564753004
"""

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=np.array([28,80,20,10,5,1]),activation="relu",verbose=True,max_iter=500)
model.fit(X_train,y_train)
print("The training accuracy of the mlp calssifier model = ",model.score(X_train,y_train))
print("The testing accuracy of the mlp calssifier model = ",model.score(X_test,y_test))

# %%
"""
Iteration 1, loss = 0.68745048
Iteration 2, loss = 0.61328793
Iteration 3, loss = 0.58680308
Iteration 4, loss = 0.57485824
Iteration 5, loss = 0.56757520
Iteration 6, loss = 0.56169286
Iteration 7, loss = 0.55600122
Iteration 8, loss = 0.55155584
Iteration 9, loss = 0.54748302
Iteration 10, loss = 0.54336003
Iteration 11, loss = 0.53990202
Iteration 12, loss = 0.53664268
Iteration 13, loss = 0.53361744
Iteration 14, loss = 0.53141963
Iteration 15, loss = 0.52932421
Iteration 16, loss = 0.52739339
Iteration 17, loss = 0.52627501
Iteration 18, loss = 0.52471154
Iteration 19, loss = 0.52304090
Iteration 20, loss = 0.52145103
Iteration 21, loss = 0.52035506
Iteration 22, loss = 0.51923272
Iteration 23, loss = 0.51799886
Iteration 24, loss = 0.51694442
Iteration 25, loss = 0.51591493
...
Iteration 237, loss = 0.49173658
Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
The training accuracy of the mlp calssifier model =  0.7570954424364305
The testing accuracy of the mlp calssifier model =  0.7511431909212283
"""

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=np.array([28,90,20,10,5,1]),activation="relu",verbose=True,max_iter=500)
model.fit(X_train,y_train)
print("The training accuracy of the mlp calssifier model = ",model.score(X_train,y_train))
print("The testing accuracy of the mlp calssifier model = ",model.score(X_test,y_test))

# %%
"""
Iteration 1, loss = 0.63489032
Iteration 2, loss = 0.59652571
Iteration 3, loss = 0.58390066
Iteration 4, loss = 0.57588641
Iteration 5, loss = 0.56911299
Iteration 6, loss = 0.56313054
Iteration 7, loss = 0.55875989
Iteration 8, loss = 0.55388210
Iteration 9, loss = 0.54979416
Iteration 10, loss = 0.54584353
Iteration 11, loss = 0.54281545
Iteration 12, loss = 0.53863568
Iteration 13, loss = 0.53532957
Iteration 14, loss = 0.53218280
Iteration 15, loss = 0.52919191
Iteration 16, loss = 0.52732464
Iteration 17, loss = 0.52500141
Iteration 18, loss = 0.52290646
Iteration 19, loss = 0.52117509
Iteration 20, loss = 0.51996747
Iteration 21, loss = 0.51843089
Iteration 22, loss = 0.51743610
Iteration 23, loss = 0.51639574
Iteration 24, loss = 0.51507098
Iteration 25, loss = 0.51462254
...
Iteration 249, loss = 0.48989499
Iteration 250, loss = 0.48990896
Iteration 251, loss = 0.48984911
Iteration 252, loss = 0.49000450
Iteration 253, loss = 0.48977481
Iteration 254, loss = 0.48993073
Iteration 255, loss = 0.48972966
Iteration 256, loss = 0.48974360
Iteration 257, loss = 0.48971701
Iteration 258, loss = 0.48955925
Iteration 259, loss = 0.48976810
Iteration 260, loss = 0.48980214
Iteration 261, loss = 0.48956286
Iteration 262, loss = 0.48954636
Iteration 263, loss = 0.48965179
Iteration 264, loss = 0.48952323
Iteration 265, loss = 0.48973570
Iteration 266, loss = 0.48955249
Iteration 267, loss = 0.48927546
Iteration 268, loss = 0.48953488
Iteration 269, loss = 0.48942162
Iteration 270, loss = 0.48948091
Iteration 271, loss = 0.48947272
Iteration 272, loss = 0.48949587
Iteration 273, loss = 0.48944514
Iteration 274, loss = 0.48930322
Iteration 275, loss = 0.48935772
Iteration 276, loss = 0.48934740
Iteration 277, loss = 0.48936215
Iteration 278, loss = 0.48931648
Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
The training accuracy of the mlp calssifier model =  0.7582553295351898
The testing accuracy of the mlp calssifier model =  0.7521028037383177
"""

# %% [markdown]
# # 4) Training Data using neural network from tensorflow

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
tf.random.set_seed(42)
X_train_1 = np.array(X_train[:,0:21])
X_train_2 = np.array(X_train[:,21:28])
X_train_1 = X_train_1.astype(np.float32)
X_train_1 = tf.convert_to_tensor(X_train_1)

X_train_2 = X_train_2.astype(np.float32)
X_train_2 = tf.convert_to_tensor(X_train_2)

X_test_1 = np.array(X_test[:,0:21])
X_test_2 = np.array(X_test[:,21:28])

X_test_1 = X_test_1.astype(np.float32)
X_test_1 = tf.convert_to_tensor(X_test_1)

X_test_2 = X_test_2.astype(np.float32)
X_test_2 = tf.convert_to_tensor(X_test_2)
early_stop = EarlyStopping(monitor='val_loss', patience=15)
model1 = tf.keras.models.Sequential([
tf.keras.layers.Dense(4000, activation='relu', kernel_regularizer=regularizers.l2(0.0009)),
tf.keras.layers.Dense(2000, activation='relu'),
tf.keras.layers.Dense(900, activation='relu'),
tf.keras.layers.Dense(200)
])
model2 = tf.keras.models.Sequential([
tf.keras.layers.Dense(3000, activation='relu'),
tf.keras.layers.Dense(1000, activation='relu'),
tf.keras.layers.Dense(500, activation='relu'),
tf.keras.layers.Dense(200 )
])
# create the user input and point to the base network
input1 = tf.keras.layers.Input(shape=(21))
vu = model1(input1)
vu = tf.linalg.l2_normalize(vu, axis=1)
# create the item input and point to the base network
input2 = tf.keras.layers.Input(shape=(7))
vm = model2(input2)
vm = tf.linalg.l2_normalize(vm, axis=1)
# measure the similarity of the two vector outputs
output = tf.keras.layers.Dot(axes=1)([vu, vm])
# specify the inputs and output of the model
model = tf.keras.models.Model([input1, input2], output)
# Specify the cost function
#cost_fn = tf.keras.losses.binary_crossentropy()

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit([X_train_1, X_train_2], y_train, epochs=100,batch_size= 200, validation_data=([X_test_1,X_test_2], y_test), callbacks=[early_stop])

loss, accuracy = model.evaluate([X_test_1,X_test_2], y_test)
loss2, accuracy2 = model.evaluate([X_train_1,X_train_2], y_train)
# Print the test loss and accuracy
print('Test accuracy:', accuracy)
print('Train accuracy:', accuracy2)

# Epoch 1/100
# 2397/2397 [==============================] - 29s 11ms/step - loss: 0.6409 - accuracy: 0.6455 - val_loss: 0.5814 - val_accuracy: 0.6931
# Epoch 2/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5815 - accuracy: 0.6928 - val_loss: 0.5824 - val_accuracy: 0.6873
# Epoch 3/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.6530 - accuracy: 0.6117 - val_loss: 0.6114 - val_accuracy: 0.6715
# Epoch 4/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5745 - accuracy: 0.7000 - val_loss: 0.5543 - val_accuracy: 0.7153
# Epoch 5/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5596 - accuracy: 0.7101 - val_loss: 0.5491 - val_accuracy: 0.7176
# Epoch 6/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5510 - accuracy: 0.7157 - val_loss: 0.5464 - val_accuracy: 0.7222
# Epoch 7/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5524 - accuracy: 0.7146 - val_loss: 0.5416 - val_accuracy: 0.7235
# Epoch 8/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5466 - accuracy: 0.7194 - val_loss: 0.5477 - val_accuracy: 0.7216
# Epoch 9/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5394 - accuracy: 0.7248 - val_loss: 0.5302 - val_accuracy: 0.7326
# Epoch 10/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5397 - accuracy: 0.7246 - val_loss: 0.5444 - val_accuracy: 0.7236
# Epoch 11/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5452 - accuracy: 0.7215 - val_loss: 0.5290 - val_accuracy: 0.7318
# Epoch 12/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5335 - accuracy: 0.7295 - val_loss: 0.5238 - val_accuracy: 0.7380
# Epoch 13/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5265 - accuracy: 0.7347 - val_loss: 0.5333 - val_accuracy: 0.7297
# Epoch 14/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5247 - accuracy: 0.7367 - val_loss: 0.5203 - val_accuracy: 0.7399
# Epoch 15/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5210 - accuracy: 0.7392 - val_loss: 0.5190 - val_accuracy: 0.7405
# Epoch 16/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5263 - accuracy: 0.7347 - val_loss: 0.5187 - val_accuracy: 0.7410
# Epoch 17/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5519 - accuracy: 0.7172 - val_loss: 0.5452 - val_accuracy: 0.7215
# Epoch 18/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5359 - accuracy: 0.7290 - val_loss: 0.5258 - val_accuracy: 0.7364
# Epoch 19/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5399 - accuracy: 0.7248 - val_loss: 0.5518 - val_accuracy: 0.7166
# Epoch 20/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5370 - accuracy: 0.7286 - val_loss: 0.5250 - val_accuracy: 0.7378
# Epoch 21/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5311 - accuracy: 0.7328 - val_loss: 0.5199 - val_accuracy: 0.7419
# Epoch 22/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5246 - accuracy: 0.7376 - val_loss: 0.5284 - val_accuracy: 0.7343
# Epoch 23/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5268 - accuracy: 0.7356 - val_loss: 0.5442 - val_accuracy: 0.7255
# Epoch 24/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5345 - accuracy: 0.7303 - val_loss: 0.5384 - val_accuracy: 0.7274
# Epoch 25/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5327 - accuracy: 0.7317 - val_loss: 0.5204 - val_accuracy: 0.7418
# Epoch 26/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5263 - accuracy: 0.7371 - val_loss: 0.5161 - val_accuracy: 0.7449
# Epoch 27/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5298 - accuracy: 0.7344 - val_loss: 0.5264 - val_accuracy: 0.7381
# Epoch 28/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5374 - accuracy: 0.7276 - val_loss: 0.5294 - val_accuracy: 0.7342
# Epoch 29/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5197 - accuracy: 0.7417 - val_loss: 0.5127 - val_accuracy: 0.7464
# Epoch 30/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5377 - accuracy: 0.7271 - val_loss: 0.5328 - val_accuracy: 0.7315
# Epoch 31/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5220 - accuracy: 0.7405 - val_loss: 0.5175 - val_accuracy: 0.7456
# Epoch 32/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5179 - accuracy: 0.7429 - val_loss: 0.6614 - val_accuracy: 0.5950
# Epoch 33/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5274 - accuracy: 0.7365 - val_loss: 0.5139 - val_accuracy: 0.7464
# Epoch 34/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5120 - accuracy: 0.7463 - val_loss: 0.5104 - val_accuracy: 0.7480
# Epoch 35/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5304 - accuracy: 0.7332 - val_loss: 0.5412 - val_accuracy: 0.7292
# Epoch 36/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5194 - accuracy: 0.7418 - val_loss: 0.5132 - val_accuracy: 0.7467
# Epoch 37/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5126 - accuracy: 0.7463 - val_loss: 0.5116 - val_accuracy: 0.7475
# Epoch 38/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5122 - accuracy: 0.7464 - val_loss: 0.5123 - val_accuracy: 0.7476
# Epoch 39/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5066 - accuracy: 0.7504 - val_loss: 0.5129 - val_accuracy: 0.7466
# Epoch 40/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5227 - accuracy: 0.7396 - val_loss: 0.5107 - val_accuracy: 0.7481
# Epoch 41/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5151 - accuracy: 0.7440 - val_loss: 0.5145 - val_accuracy: 0.7466
# Epoch 42/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5230 - accuracy: 0.7401 - val_loss: 0.5179 - val_accuracy: 0.7441
# Epoch 43/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5255 - accuracy: 0.7385 - val_loss: 0.5138 - val_accuracy: 0.7465
# Epoch 44/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5138 - accuracy: 0.7454 - val_loss: 0.5149 - val_accuracy: 0.7451
# Epoch 45/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5089 - accuracy: 0.7495 - val_loss: 0.5106 - val_accuracy: 0.7502
# Epoch 46/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5033 - accuracy: 0.7525 - val_loss: 0.5147 - val_accuracy: 0.7514
# Epoch 47/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5075 - accuracy: 0.7500 - val_loss: 0.5099 - val_accuracy: 0.7507
# Epoch 48/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5014 - accuracy: 0.7544 - val_loss: 0.5094 - val_accuracy: 0.7506
# Epoch 49/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5163 - accuracy: 0.7437 - val_loss: 0.5090 - val_accuracy: 0.7508
# Epoch 50/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5054 - accuracy: 0.7510 - val_loss: 0.5065 - val_accuracy: 0.7516
# Epoch 51/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5136 - accuracy: 0.7455 - val_loss: 0.5214 - val_accuracy: 0.7403
# Epoch 52/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5048 - accuracy: 0.7515 - val_loss: 0.5091 - val_accuracy: 0.7514
# Epoch 53/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.4974 - accuracy: 0.7567 - val_loss: 0.5117 - val_accuracy: 0.7521
# Epoch 54/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.4970 - accuracy: 0.7569 - val_loss: 0.5160 - val_accuracy: 0.7448
# Epoch 55/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5003 - accuracy: 0.7549 - val_loss: 0.5090 - val_accuracy: 0.7523
# Epoch 56/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5134 - accuracy: 0.7459 - val_loss: 0.5227 - val_accuracy: 0.7412
# Epoch 57/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5109 - accuracy: 0.7490 - val_loss: 0.5190 - val_accuracy: 0.7457
# Epoch 58/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5158 - accuracy: 0.7458 - val_loss: 0.5192 - val_accuracy: 0.7451
# Epoch 59/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5065 - accuracy: 0.7526 - val_loss: 0.5167 - val_accuracy: 0.7500
# Epoch 60/100
# 2397/2397 [==============================] - 25s 10ms/step - loss: 0.5025 - accuracy: 0.7544 - val_loss: 0.5109 - val_accuracy: 0.7511
# Epoch 61/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.4970 - accuracy: 0.7580 - val_loss: 0.5084 - val_accuracy: 0.7525
# Epoch 62/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.4948 - accuracy: 0.7591 - val_loss: 0.5094 - val_accuracy: 0.7536
# Epoch 63/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.4995 - accuracy: 0.7558 - val_loss: 0.5111 - val_accuracy: 0.7529
# Epoch 64/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.5014 - accuracy: 0.7538 - val_loss: 0.5155 - val_accuracy: 0.7484
# Epoch 65/100
# 2397/2397 [==============================] - 24s 10ms/step - loss: 0.4902 - accuracy: 0.7626 - val_loss: 0.5094 - val_accuracy: 0.7509
# 3745/3745 [==============================] - 12s 3ms/step - loss: 0.5094 - accuracy: 0.7509
# 14980/14980 [==============================] - 48s 3ms/step - loss: 0.4860 - accuracy: 0.7642
# Test accuracy: 0.7509012222290039
# Train accuracy: 0.7642383575439453

# %%
tensorflowModel = Sequential([Dense(units= 530, activation='relu', kernel_regularizer = regularizers.l2(0.0001)), Dense(units= 125, activation='relu' ), Dense(units= 1, activation= 'sigmoid' )])

tensorflowModel.compile(loss = BinaryCrossentropy(), optimizer ='adam', metrics ='accuracy')

tensorflowModel.fit(X_train, y_train, batch_size = 50, epochs = 10)
loss, train_accuracy = tensorflowModel.evaluate(X_train, y_train)
loss1, test_accuracy = tensorflowModel.evaluate(X_test, y_test)
print(train_accuracy)
print(test_accuracy)

# %%
"""
Epoch 1/10
9588/9588 [==============================] - 62s 6ms/step - loss: 0.6082 - accuracy: 0.6692
Epoch 2/10
9588/9588 [==============================] - 59s 6ms/step - loss: 0.5775 - accuracy: 0.6995
Epoch 3/10
9588/9588 [==============================] - 59s 6ms/step - loss: 0.5641 - accuracy: 0.7111
Epoch 4/10
9588/9588 [==============================] - 60s 6ms/step - loss: 0.5557 - accuracy: 0.7179
Epoch 5/10
9588/9588 [==============================] - 63s 7ms/step - loss: 0.5492 - accuracy: 0.7231
Epoch 6/10
9588/9588 [==============================] - 62s 6ms/step - loss: 0.5444 - accuracy: 0.7275
Epoch 7/10
9588/9588 [==============================] - 58s 6ms/step - loss: 0.5405 - accuracy: 0.7300
Epoch 8/10
9588/9588 [==============================] - 58s 6ms/step - loss: 0.5382 - accuracy: 0.7318
Epoch 9/10
9588/9588 [==============================] - 61s 6ms/step - loss: 0.5360 - accuracy: 0.7334
Epoch 10/10
9588/9588 [==============================] - 63s 7ms/step - loss: 0.5339 - accuracy: 0.7354
14980/14980 [==============================] - 43s 3ms/step - loss: 0.5289 - accuracy: 0.7400
3745/3745 [==============================] - 10s 3ms/step - loss: 0.5333 - accuracy: 0.7351
0.7399892210960388
0.7351385354995728
"""

# %%
import tensorflow as tf

from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras import regularizers

tf.random.set_seed(42)

X_train_1 = np.array(X_train[:,0:21])

X_train_2 = np.array(X_train[:,21:28])

X_train_1 = X_train_1.astype(np.float32)

X_train_1 = tf.convert_to_tensor(X_train_1)

 

X_train_2 = X_train_2.astype(np.float32)

X_train_2 = tf.convert_to_tensor(X_train_2)

 

X_test_1 = np.array(X_test[:,0:21])

X_test_2 = np.array(X_test[:,21:28])

 

X_test_1 = X_test_1.astype(np.float32)

X_test_1 = tf.convert_to_tensor(X_test_1)

 

X_test_2 = X_test_2.astype(np.float32)

X_test_2 = tf.convert_to_tensor(X_test_2)

early_stop = EarlyStopping(monitor='val_loss', patience=15)

model1 = tf.keras.models.Sequential([

tf.keras.layers.Dense(3000, activation='relu', kernel_regularizer=regularizers.l2(0.0005)),

tf.keras.layers.Dense(1000, activation='relu'),

tf.keras.layers.Dense(900, activation='relu'),

tf.keras.layers.Dense(200)

])

model2 = tf.keras.models.Sequential([

tf.keras.layers.Dense(1000, activation='relu'),

tf.keras.layers.Dense(500, activation='relu'),

tf.keras.layers.Dense(128, activation='relu'),

tf.keras.layers.Dense(200 )

])

# create the user input and point to the base network

input1 = tf.keras.layers.Input(shape=(21))

vu = model1(input1)

vu = tf.linalg.l2_normalize(vu, axis=1)

# create the item input and point to the base network

input2 = tf.keras.layers.Input(shape=(7))

vm = model2(input2)

vm = tf.linalg.l2_normalize(vm, axis=1)

# measure the similarity of the two vector outputs

output = tf.keras.layers.Dot(axes=1)([vu, vm])

# specify the inputs and output of the model

model = tf.keras.models.Model([input1, input2], output)

# Specify the cost function

#cost_fn = tf.keras.losses.binary_crossentropy()

 

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

 

# Train the model

model.fit([X_train_1, X_train_2], y_train, epochs=100,batch_size= 1000, validation_data=([X_test_1,X_test_2], y_test), callbacks=[early_stop])

 

loss, accuracy = model.evaluate([X_test_1,X_test_2], y_test)

loss2, accuracy2 = model.evaluate([X_train_1,X_train_2], y_train)

# Print the test loss and accuracy

print('Test accuracy:', accuracy)

print('Train accuracy:', accuracy2)

# %%
"""
Epoch 1/100
480/480 [==============================] - 138s 281ms/step - loss: 0.6258 - accuracy: 0.6684 - val_loss: 0.6028 - val_accuracy: 0.6982
Epoch 2/100
480/480 [==============================] - 135s 281ms/step - loss: 0.5719 - accuracy: 0.7058 - val_loss: 0.5673 - val_accuracy: 0.7095
Epoch 3/100
480/480 [==============================] - 134s 279ms/step - loss: 0.5636 - accuracy: 0.7098 - val_loss: 0.5542 - val_accuracy: 0.7135
Epoch 4/100
480/480 [==============================] - 134s 279ms/step - loss: 0.5501 - accuracy: 0.7180 - val_loss: 0.5470 - val_accuracy: 0.7210
Epoch 5/100
480/480 [==============================] - 134s 280ms/step - loss: 0.5441 - accuracy: 0.7233 - val_loss: 0.5386 - val_accuracy: 0.7274
Epoch 6/100
480/480 [==============================] - 135s 281ms/step - loss: 0.5378 - accuracy: 0.7271 - val_loss: 0.5389 - val_accuracy: 0.7276
Epoch 7/100
480/480 [==============================] - 134s 279ms/step - loss: 0.5390 - accuracy: 0.7264 - val_loss: 0.5307 - val_accuracy: 0.7320
Epoch 8/100
480/480 [==============================] - 134s 279ms/step - loss: 0.5328 - accuracy: 0.7314 - val_loss: 0.5448 - val_accuracy: 0.7293
Epoch 9/100
480/480 [==============================] - 134s 279ms/step - loss: 0.5349 - accuracy: 0.7299 - val_loss: 0.5395 - val_accuracy: 0.7259
Epoch 10/100
480/480 [==============================] - 134s 278ms/step - loss: 0.5479 - accuracy: 0.7194 - val_loss: 0.5847 - val_accuracy: 0.6993
Epoch 11/100
480/480 [==============================] - 130s 271ms/step - loss: 0.5387 - accuracy: 0.7275 - val_loss: 0.5537 - val_accuracy: 0.7155
Epoch 12/100
480/480 [==============================] - 134s 279ms/step - loss: 0.5290 - accuracy: 0.7345 - val_loss: 0.5300 - val_accuracy: 0.7358
Epoch 13/100
...
3745/3745 [==============================] - 42s 11ms/step - loss: 0.5444 - accuracy: 0.7273
14980/14980 [==============================] - 161s 11ms/step - loss: 0.5393 - accuracy: 0.7302
Test accuracy: 0.727344810962677
Train accuracy: 0.730219841003418
"""
