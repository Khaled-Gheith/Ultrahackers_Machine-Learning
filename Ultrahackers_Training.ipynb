# %% [markdown]
# # Data Cleaning

# %% [markdown]
# First we imported the data using pandas. We noticed that the data is missing headers so we added labels for each column.

# %%
import pandas as pd
import numpy as np
import io
from google.colab import files
from google.colab import drive
import os
drive.mount('/content/gdrive', force_remount=True)




numOfHeaders = 29

#set the labels for the features
headers = ["feature "+str(i) for i in range(1,numOfHeaders)]

# mark the first column to be the target
headers = ["output"] + headers
data= pd.read_csv('/content/gdrive/MyDrive/HIGGS_train.csv', names = headers, low_memory= False)
#import the data and set the columns' headers to the labels

data
# Out:
# Mounted at /content/gdrive
#         output  feature 1  feature 2  feature 3  feature 4  feature 5  \
# 0          1.0      0.869     -0.635      0.226      0.327     -0.690
# 1          1.0      0.908      0.329      0.359      1.500     -0.313
# 2          1.0      0.799      1.470     -1.640      0.454      0.426
# 3          0.0      1.340     -0.877      0.936      1.990      0.882
# 4          1.0      1.110      0.321      1.520      0.883     -1.210
# ...        ...        ...        ...        ...        ...        ...
# 599995     0.0      0.680      0.223     -0.757      0.418     -0.323
# 599996     1.0      1.610     -1.620      0.212      0.716     -0.906
# 599997     1.0      1.070      0.364      0.344      0.617     -1.430
# 599998     1.0      1.180     -0.173     -1.460      0.735     -0.753
# 599999     0.0      0.771     -0.133     -1.020      1.790     -1.650
#
#         feature 6  feature 7  feature 8  feature 9  ...  feature 19  \
# ...

# %% [markdown]
# We noticed that there are some duplicated rows that we dropped down.

# %%
numOfDuplicatedRows = len(np.where(data.duplicated() == True)[0])
print("The number of duplicated rows = ",numOfDuplicatedRows)

data = data.drop_duplicates()
data
# Out:
# The number of duplicated rows =  802
#         output  feature 1  feature 2  feature 3  feature 4  feature 5  \
# 0          1.0      0.869     -0.635      0.226      0.327     -0.690
# 1          1.0      0.908      0.329      0.359      1.500     -0.313
# 2          1.0      0.799      1.470     -1.640      0.454      0.426
# 3          0.0      1.340     -0.877      0.936      1.990      0.882
# 4          1.0      1.110      0.321      1.520      0.883     -1.210
# ...        ...        ...        ...        ...        ...        ...
# 599995     0.0      0.680      0.223     -0.757      0.418     -0.323
# 599996     1.0      1.610     -1.620      0.212      0.716     -0.906
# 599997     1.0      1.070      0.364      0.344      0.617     -1.430
# 599998     1.0      1.180     -0.173     -1.460      0.735     -0.753
# 599999     0.0      0.771     -0.133     -1.020      1.790     -1.650
#
#         feature 6  feature 7  feature 8  feature 9  ...  feature 19  \
# ...

# %% [markdown]
# We searched for rows with missing data, and we got their indices and dropped them accordingly.

# %%
print("The number of rows that have null values is : ", len(np.where(data.isna().any(axis=1) == True)[0]))
#get the row with the missing data
rows = data[data.isna().any(axis=1)]
#get the index of that row and drop it
data = data.drop(rows.index,axis=0)
data
# Out:
# The number of rows that have null values is :  1
#         output  feature 1  feature 2  feature 3  feature 4  feature 5  \
# 0          1.0      0.869     -0.635      0.226      0.327     -0.690
# 1          1.0      0.908      0.329      0.359      1.500     -0.313
# 2          1.0      0.799      1.470     -1.640      0.454      0.426
# 3          0.0      1.340     -0.877      0.936      1.990      0.882
# 4          1.0      1.110      0.321      1.520      0.883     -1.210
# ...        ...        ...        ...        ...        ...        ...
# 599995     0.0      0.680      0.223     -0.757      0.418     -0.323
# 599996     1.0      1.610     -1.620      0.212      0.716     -0.906
# 599997     1.0      1.070      0.364      0.344      0.617     -1.430
# 599998     1.0      1.180     -0.173     -1.460      0.735     -0.753
# 599999     0.0      0.771     -0.133     -1.020      1.790     -1.650
#
#         feature 6  feature 7  feature 8  feature 9  ...  feature 19  \
# ...

# %% [markdown]
# We noticed that the data is not of the same type. We got the indices of the columns and the rows where the data is of type string. we looped over the cells with string data and converted them to float if applicable. if not, we replaced them with the mode of the column.

# %%
print("Is the data of the same type?",data.dtypes.nunique() == 1)
#get the indices of the columns that have non float values 
cols = np.where(data.dtypes != "float64")
#get the headers of those rows
cols = np.array([headers[i] for i in cols[0]])
#create a copy of the data
copyOfData = data
#convert everything to numeric type, if a data cell is non numeric, it will be converted to nan
copyOfData = copyOfData.apply(pd.to_numeric,errors='coerce')
#indices of the rows that contains non numeric values 
indices = np.where(copyOfData.isna().any(axis = 1))[0]

#loop over the rows
for row in indices:
    #loop over the elements of the row
    for col in cols:
        #get the element at that row at that col
        num = data.iloc[row][col]
        try: 
            #if applicable, get the numeric value of the string
            data = data.replace({col:{num:float(num.strip('"'))}})
        except:
            #replace the field with the mode
            data = data.replace({col:{num:data[col].mode()[0]}}) 
data
# Out:
# Is the data of the same type? False
#         output  feature 1  feature 2  feature 3  feature 4  feature 5  \
# 0          1.0      0.869     -0.635      0.226      0.327     -0.690
# 1          1.0      0.908      0.329      0.359      1.500     -0.313
# 2          1.0      0.799      1.470     -1.640      0.454      0.426
# 3          0.0      1.340     -0.877      0.936      1.990      0.882
# 4          1.0      1.110      0.321      1.520      0.883     -1.210
# ...        ...        ...        ...        ...        ...        ...
# 599995     0.0      0.680      0.223     -0.757      0.418     -0.323
# 599996     1.0      1.610     -1.620      0.212      0.716     -0.906
# 599997     1.0      1.070      0.364      0.344      0.617     -1.430
# 599998     1.0      1.180     -0.173     -1.460      0.735     -0.753
# 599999     0.0      0.771     -0.133     -1.020      1.790     -1.650
#
#         feature 6  feature 7  feature 8  feature 9  ...  feature 19  \
# ...

# %% [markdown]
# # Data Training:

# %% [markdown]
# # 1) Training the data with the logistic regression model:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

y = np.array(data.iloc[:,0])
X = np.array(data.iloc[:,1:])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model= LogisticRegression()
model.fit(X_train, y_train)
print("The accuracy of the logistic regression model = ",model.score(X_test,y_test))
# Out:
# The accuracy of the logistic regression model =  0.6407877169559413

# %% [markdown]
# # 2) Training the data with the neural networks from sklearn MLPClassifier

# %%
from sklearn.neural_network import MLPClassifier

m_0 = MLPClassifier(hidden_layer_sizes= np.array([100, 99, 95, 85, 70, 50, 35, 20, 5, 1]), solver = 'sgd', alpha=0.0001, verbose=True, shuffle=True)
m_0.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_0.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_0.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.69159535
# Iteration 2, loss = 0.66536958
# Iteration 3, loss = 0.64130915
# Iteration 4, loss = 0.62838088
# Iteration 5, loss = 0.61423500
# Iteration 6, loss = 0.60164229
# Iteration 7, loss = 0.59409644
# Iteration 8, loss = 0.58851740
# Iteration 9, loss = 0.58370685
# Iteration 10, loss = 0.57943136
# Iteration 11, loss = 0.57507557
# Iteration 12, loss = 0.57093447
# Iteration 13, loss = 0.56709988
# Iteration 14, loss = 0.56355954
# Iteration 15, loss = 0.56026560
# Iteration 16, loss = 0.55748842
# Iteration 17, loss = 0.55453619
# Iteration 18, loss = 0.55200393
# Iteration 19, loss = 0.54979797
# Iteration 20, loss = 0.54740334
# Iteration 21, loss = 0.54542718
# Iteration 22, loss = 0.54327626
# Iteration 23, loss = 0.54137954
# Iteration 24, loss = 0.53930904
# Iteration 25, loss = 0.53784106
# Iteration 26, loss = 0.53601981
# Iteration 27, loss = 0.53430342
# Iteration 28, loss = 0.53268609
# Iteration 29, loss = 0.53124472
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_1 = MLPClassifier(hidden_layer_sizes= np.array([100, 97, 89, 83, 79, 73, 71, 67, 61, 59, 53, 47, 43, 41, 37, 31, 29, 23, 19, 17, 13, 11, 7, 5, 3, 2, 1]), solver = 'sgd', alpha=0.0001, verbose=True, shuffle=True)
m_1.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_1.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_1.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.72033929
# Iteration 2, loss = 0.69168231
# Iteration 3, loss = 0.69168021
# Iteration 4, loss = 0.69167922
# Iteration 5, loss = 0.69167873
# Iteration 6, loss = 0.69168088
# Iteration 7, loss = 0.69167831
# Iteration 8, loss = 0.69168120
# Iteration 9, loss = 0.69168080
# Iteration 10, loss = 0.69168041
# Iteration 11, loss = 0.69167813
# Iteration 12, loss = 0.69167927
# Iteration 13, loss = 0.69168198
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# The training accuracy of the mlp classifier model =  0.5296490924300677
# The testing accuracy of the mlp classifier model =  0.5313751668891856

# %%
from sklearn.neural_network import MLPClassifier

m_2 = MLPClassifier(hidden_layer_sizes= np.array([100, 90, 50, 1]), solver = 'adam', alpha=0.005, verbose=True, shuffle=True)
m_2.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_2.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_2.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.61956052
# Iteration 2, loss = 0.58348783
# Iteration 3, loss = 0.56657989
# Iteration 4, loss = 0.55592349
# Iteration 5, loss = 0.54746455
# Iteration 6, loss = 0.54081682
# Iteration 7, loss = 0.53585163
# Iteration 8, loss = 0.53136786
# Iteration 9, loss = 0.52789096
# Iteration 10, loss = 0.52391223
# Iteration 11, loss = 0.52068403
# Iteration 12, loss = 0.51793449
# Iteration 13, loss = 0.51599838
# Iteration 14, loss = 0.51403667
# Iteration 15, loss = 0.51192247
# Iteration 16, loss = 0.51086931
# Iteration 17, loss = 0.50920963
# Iteration 18, loss = 0.50856276
# Iteration 19, loss = 0.50723572
# Iteration 20, loss = 0.50637269
# Iteration 21, loss = 0.50594127
# Iteration 22, loss = 0.50478185
# Iteration 23, loss = 0.50404052
# Iteration 24, loss = 0.50359359
# Iteration 25, loss = 0.50247457
# Iteration 26, loss = 0.50226523
# Iteration 27, loss = 0.50159079
# Iteration 28, loss = 0.50110312
# Iteration 29, loss = 0.50028659
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_3 = MLPClassifier(hidden_layer_sizes= np.array([100, 70, 10, 1]), solver = 'adam', alpha= 0.03, verbose=True, shuffle=True)
m_3.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_3.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_3.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.62253005
# Iteration 2, loss = 0.58853618
# Iteration 3, loss = 0.57359627
# Iteration 4, loss = 0.56400639
# Iteration 5, loss = 0.55652272
# Iteration 6, loss = 0.55050442
# Iteration 7, loss = 0.54512415
# Iteration 8, loss = 0.54107328
# Iteration 9, loss = 0.53746180
# Iteration 10, loss = 0.53476140
# Iteration 11, loss = 0.53260336
# Iteration 12, loss = 0.53021286
# Iteration 13, loss = 0.52934736
# Iteration 14, loss = 0.52737378
# Iteration 15, loss = 0.52684230
# Iteration 16, loss = 0.52610351
# Iteration 17, loss = 0.52476930
# Iteration 18, loss = 0.52391988
# Iteration 19, loss = 0.52375523
# Iteration 20, loss = 0.52234817
# Iteration 21, loss = 0.52234475
# Iteration 22, loss = 0.52128695
# Iteration 23, loss = 0.52081291
# Iteration 24, loss = 0.51983474
# Iteration 25, loss = 0.51971901
# Iteration 26, loss = 0.51941409
# Iteration 27, loss = 0.51872206
# Iteration 28, loss = 0.51885448
# Iteration 29, loss = 0.51844026
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_4 = MLPClassifier(hidden_layer_sizes= np.array([28, 25, 16, 10, 1]), solver = 'adam', alpha= 0.0001, verbose=True, shuffle=True)
m_4.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_4.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_4.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.63634214
# Iteration 2, loss = 0.59800875
# Iteration 3, loss = 0.58420555
# Iteration 4, loss = 0.57603762
# Iteration 5, loss = 0.57046078
# Iteration 6, loss = 0.56618595
# Iteration 7, loss = 0.56159788
# Iteration 8, loss = 0.55771710
# Iteration 9, loss = 0.55409973
# Iteration 10, loss = 0.55070967
# Iteration 11, loss = 0.54753641
# Iteration 12, loss = 0.54468992
# Iteration 13, loss = 0.54244108
# Iteration 14, loss = 0.54022524
# Iteration 15, loss = 0.53887918
# Iteration 16, loss = 0.53726585
# Iteration 17, loss = 0.53590363
# Iteration 18, loss = 0.53452435
# Iteration 19, loss = 0.53301020
# Iteration 20, loss = 0.53176762
# Iteration 21, loss = 0.53141461
# Iteration 22, loss = 0.53027395
# Iteration 23, loss = 0.52899906
# Iteration 24, loss = 0.52826108
# Iteration 25, loss = 0.52740477
# Iteration 26, loss = 0.52680536
# Iteration 27, loss = 0.52583129
# Iteration 28, loss = 0.52530551
# Iteration 29, loss = 0.52459394
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_5 = MLPClassifier(hidden_layer_sizes= np.array([100, 90, 40, 5, 1]), solver = 'adam', alpha= 0.008, verbose=True, shuffle=True)
m_5.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_5.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_5.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.61753098
# Iteration 2, loss = 0.58128748
# Iteration 3, loss = 0.56510885
# Iteration 4, loss = 0.55423165
# Iteration 5, loss = 0.54700474
# Iteration 6, loss = 0.54059656
# Iteration 7, loss = 0.53586476
# Iteration 8, loss = 0.53113776
# Iteration 9, loss = 0.52707304
# Iteration 10, loss = 0.52356394
# Iteration 11, loss = 0.52112804
# Iteration 12, loss = 0.51842094
# Iteration 13, loss = 0.51613406
# Iteration 14, loss = 0.51465654
# Iteration 15, loss = 0.51246155
# Iteration 16, loss = 0.51178334
# Iteration 17, loss = 0.51096161
# Iteration 18, loss = 0.50940339
# Iteration 19, loss = 0.50848199
# Iteration 20, loss = 0.50807287
# Iteration 21, loss = 0.50672097
# Iteration 22, loss = 0.50604898
# Iteration 23, loss = 0.50528229
# Iteration 24, loss = 0.50478331
# Iteration 25, loss = 0.50423833
# Iteration 26, loss = 0.50398351
# Iteration 27, loss = 0.50339423
# Iteration 28, loss = 0.50308151
# Iteration 29, loss = 0.50244181
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_6 = MLPClassifier(hidden_layer_sizes= np.array([100, 100, 1]), alpha = 0.01, verbose=True, shuffle=True)
m_6.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_6.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_6.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.62381968
# Iteration 2, loss = 0.59166327
# Iteration 3, loss = 0.57600296
# Iteration 4, loss = 0.56593313
# Iteration 5, loss = 0.55881818
# Iteration 6, loss = 0.55262745
# Iteration 7, loss = 0.54764248
# Iteration 8, loss = 0.54313483
# Iteration 9, loss = 0.53909203
# Iteration 10, loss = 0.53547836
# Iteration 11, loss = 0.53301425
# Iteration 12, loss = 0.53099609
# Iteration 13, loss = 0.52913808
# Iteration 14, loss = 0.52692639
# Iteration 15, loss = 0.52576974
# Iteration 16, loss = 0.52466150
# Iteration 17, loss = 0.52355238
# Iteration 18, loss = 0.52271497
# Iteration 19, loss = 0.52220682
# Iteration 20, loss = 0.52068893
# Iteration 21, loss = 0.52026407
# Iteration 22, loss = 0.51975528
# Iteration 23, loss = 0.51879062
# Iteration 24, loss = 0.51817177
# Iteration 25, loss = 0.51790226
# Iteration 26, loss = 0.51734492
# Iteration 27, loss = 0.51635232
# Iteration 28, loss = 0.51627095
# Iteration 29, loss = 0.51568230
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_7 = MLPClassifier(hidden_layer_sizes= np.array([100, 28, 20, 10, 1]), alpha = 0.01, verbose=True, shuffle=True)
m_7.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_7.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_7.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.62254136
# Iteration 2, loss = 0.58856267
# Iteration 3, loss = 0.57701621
# Iteration 4, loss = 0.56769669
# Iteration 5, loss = 0.55930436
# Iteration 6, loss = 0.55323001
# Iteration 7, loss = 0.54789699
# Iteration 8, loss = 0.54416171
# Iteration 9, loss = 0.54067730
# Iteration 10, loss = 0.53749222
# Iteration 11, loss = 0.53426393
# Iteration 12, loss = 0.53113625
# Iteration 13, loss = 0.52889711
# Iteration 14, loss = 0.52667093
# Iteration 15, loss = 0.52504330
# Iteration 16, loss = 0.52290212
# Iteration 17, loss = 0.52173227
# Iteration 18, loss = 0.52064653
# Iteration 19, loss = 0.51939768
# Iteration 20, loss = 0.51842724
# Iteration 21, loss = 0.51743474
# Iteration 22, loss = 0.51657897
# Iteration 23, loss = 0.51615393
# Iteration 24, loss = 0.51522896
# Iteration 25, loss = 0.51462078
# Iteration 26, loss = 0.51392133
# Iteration 27, loss = 0.51383663
# Iteration 28, loss = 0.51324524
# Iteration 29, loss = 0.51273276
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_8 = MLPClassifier(hidden_layer_sizes= np.array([100, 28, 58, 10, 1]), alpha = 0.01, verbose=True, shuffle=True)
m_8.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_8.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_8.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.61739217
# Iteration 2, loss = 0.58367387
# Iteration 3, loss = 0.56888596
# Iteration 4, loss = 0.55916353
# Iteration 5, loss = 0.55198665
# Iteration 6, loss = 0.54576708
# Iteration 7, loss = 0.54137741
# Iteration 8, loss = 0.53770991
# Iteration 9, loss = 0.53487515
# Iteration 10, loss = 0.53274147
# Iteration 11, loss = 0.53109377
# Iteration 12, loss = 0.52941908
# Iteration 13, loss = 0.52742954
# Iteration 14, loss = 0.52621018
# Iteration 15, loss = 0.52411388
# Iteration 16, loss = 0.52299591
# Iteration 17, loss = 0.52161012
# Iteration 18, loss = 0.52064745
# Iteration 19, loss = 0.51927561
# Iteration 20, loss = 0.51843772
# Iteration 21, loss = 0.51711335
# Iteration 22, loss = 0.51665579
# Iteration 23, loss = 0.51540522
# Iteration 24, loss = 0.51494222
# Iteration 25, loss = 0.51372320
# Iteration 26, loss = 0.51312969
# Iteration 27, loss = 0.51302104
# Iteration 28, loss = 0.51218700
# Iteration 29, loss = 0.51158259
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_9 = MLPClassifier(hidden_layer_sizes= np.array([70, 60, 30, 58, 10, 1]), alpha = 0.0001, verbose=True, shuffle=True)
m_9.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_9.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_9.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.61653926
# Iteration 2, loss = 0.58075718
# Iteration 3, loss = 0.56552953
# Iteration 4, loss = 0.55554319
# Iteration 5, loss = 0.54812126
# Iteration 6, loss = 0.54107831
# Iteration 7, loss = 0.53572963
# Iteration 8, loss = 0.53174714
# Iteration 9, loss = 0.52785892
# Iteration 10, loss = 0.52405940
# Iteration 11, loss = 0.52109535
# Iteration 12, loss = 0.51881039
# Iteration 13, loss = 0.51633030
# Iteration 14, loss = 0.51418970
# Iteration 15, loss = 0.51282068
# Iteration 16, loss = 0.51118837
# Iteration 17, loss = 0.50980685
# Iteration 18, loss = 0.50850090
# Iteration 19, loss = 0.50721715
# Iteration 20, loss = 0.50622259
# Iteration 21, loss = 0.50502117
# Iteration 22, loss = 0.50424992
# Iteration 23, loss = 0.50301764
# Iteration 24, loss = 0.50248689
# Iteration 25, loss = 0.50168362
# Iteration 26, loss = 0.50083935
# Iteration 27, loss = 0.49990425
# Iteration 28, loss = 0.49930852
# Iteration 29, loss = 0.49910470
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_10 = MLPClassifier(hidden_layer_sizes= np.array([70, 60, 30, 58, 10, 1]), alpha = 0.0001, verbose=True, shuffle=True, max_iter = 300)
m_10.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_10.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_10.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.69197927
# Iteration 2, loss = 0.69137288
# Iteration 3, loss = 0.69135674
# Iteration 4, loss = 0.69135685
# Iteration 5, loss = 0.69134916
# Iteration 6, loss = 0.69135381
# Iteration 7, loss = 0.69135421
# Iteration 8, loss = 0.69135494
# Iteration 9, loss = 0.69135552
# Iteration 10, loss = 0.69135110
# Iteration 11, loss = 0.69135145
# Iteration 12, loss = 0.69134631
# Iteration 13, loss = 0.69135462
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# The training accuracy of the mlp classifier model =  0.5300204231919008
# The testing accuracy of the mlp classifier model =  0.5298898531375167

# %%
from sklearn.neural_network import MLPClassifier

m_11 = MLPClassifier(hidden_layer_sizes= np.array([99, 88, 77, 66, 55, 44, 33, 22, 11, 1]), verbose=True, shuffle=True, max_iter = 300)
m_11.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_11.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_11.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.61751397
# Iteration 2, loss = 0.58063423
# Iteration 3, loss = 0.56231896
# Iteration 4, loss = 0.55113027
# Iteration 5, loss = 0.54289163
# Iteration 6, loss = 0.53620824
# Iteration 7, loss = 0.53098345
# Iteration 8, loss = 0.52632225
# Iteration 9, loss = 0.52167762
# Iteration 10, loss = 0.51836432
# Iteration 11, loss = 0.51520249
# Iteration 12, loss = 0.51219749
# Iteration 13, loss = 0.50941622
# Iteration 14, loss = 0.50681628
# Iteration 15, loss = 0.50536667
# Iteration 16, loss = 0.50289317
# Iteration 17, loss = 0.50087542
# Iteration 18, loss = 0.49958170
# Iteration 19, loss = 0.49752282
# Iteration 20, loss = 0.49630208
# Iteration 21, loss = 0.49554410
# Iteration 22, loss = 0.49389406
# Iteration 23, loss = 0.49278222
# Iteration 24, loss = 0.49242504
# Iteration 25, loss = 0.49086132
# Iteration 26, loss = 0.48998164
# Iteration 27, loss = 0.48872808
# Iteration 28, loss = 0.48865231
# Iteration 29, loss = 0.48752290
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_12 = MLPClassifier(hidden_layer_sizes= np.array([75, 90, 1]), solver='sgd', verbose=True, max_iter = 300)
m_12.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_12.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_12.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.67822797
# Iteration 2, loss = 0.64347200
# Iteration 3, loss = 0.63364164
# Iteration 4, loss = 0.62719155
# Iteration 5, loss = 0.62148049
# Iteration 6, loss = 0.61555797
# Iteration 7, loss = 0.60933836
# Iteration 8, loss = 0.60348906
# Iteration 9, loss = 0.59904283
# Iteration 10, loss = 0.59622016
# Iteration 11, loss = 0.59401891
# Iteration 12, loss = 0.59220766
# Iteration 13, loss = 0.59062175
# Iteration 14, loss = 0.58893896
# Iteration 15, loss = 0.58729080
# Iteration 16, loss = 0.58564161
# Iteration 17, loss = 0.58416126
# Iteration 18, loss = 0.58258393
# Iteration 19, loss = 0.58089694
# Iteration 20, loss = 0.57942729
# Iteration 21, loss = 0.57774486
# Iteration 22, loss = 0.57630569
# Iteration 23, loss = 0.57464280
# Iteration 24, loss = 0.57313424
# Iteration 25, loss = 0.57166750
# Iteration 26, loss = 0.57013196
# Iteration 27, loss = 0.56863336
# Iteration 28, loss = 0.56729721
# Iteration 29, loss = 0.56596054
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_13 = MLPClassifier(hidden_layer_sizes= np.array([62, 58, 25, 1]), solver='sgd', verbose=True, max_iter = 500)
m_13.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_13.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_13.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.69059256
# Iteration 2, loss = 0.65937303
# Iteration 3, loss = 0.64162490
# Iteration 4, loss = 0.63441704
# Iteration 5, loss = 0.62895589
# Iteration 6, loss = 0.62337328
# Iteration 7, loss = 0.61708420
# Iteration 8, loss = 0.61075309
# Iteration 9, loss = 0.60478816
# Iteration 10, loss = 0.60005022
# Iteration 11, loss = 0.59640471
# Iteration 12, loss = 0.59334062
# Iteration 13, loss = 0.59106698
# Iteration 14, loss = 0.58880345
# Iteration 15, loss = 0.58671962
# Iteration 16, loss = 0.58470079
# Iteration 17, loss = 0.58268301
# Iteration 18, loss = 0.58068070
# Iteration 19, loss = 0.57866560
# Iteration 20, loss = 0.57673086
# Iteration 21, loss = 0.57481296
# Iteration 22, loss = 0.57284549
# Iteration 23, loss = 0.57082697
# Iteration 24, loss = 0.56889473
# Iteration 25, loss = 0.56691339
# Iteration 26, loss = 0.56492806
# Iteration 27, loss = 0.56309306
# Iteration 28, loss = 0.56119076
# Iteration 29, loss = 0.55924839
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_14 = MLPClassifier(hidden_layer_sizes= np.array([69, 29, 13, 1]), solver='sgd', verbose=True, max_iter = 500)
m_14.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_14.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_14.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.69207913
# Iteration 2, loss = 0.69139178
# Iteration 3, loss = 0.69138957
# Iteration 4, loss = 0.69139216
# Iteration 5, loss = 0.69138912
# Iteration 6, loss = 0.69138999
# Iteration 7, loss = 0.69138933
# Iteration 8, loss = 0.69139019
# Iteration 9, loss = 0.69138955
# Iteration 10, loss = 0.69139103
# Iteration 11, loss = 0.69139216
# Iteration 12, loss = 0.69139053
# Iteration 13, loss = 0.69139166
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# The training accuracy of the mlp classifier model =  0.5298702219848672
# The testing accuracy of the mlp classifier model =  0.5304906542056075

# %%
from sklearn.neural_network import MLPClassifier

m_15 = MLPClassifier(hidden_layer_sizes= np.array([82, 17, 7, 1]), solver='sgd', verbose=True, max_iter = 500)
m_15.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_15.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_15.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.68143542
# Iteration 2, loss = 0.65543589
# Iteration 3, loss = 0.64245304
# Iteration 4, loss = 0.63642143
# Iteration 5, loss = 0.63192683
# Iteration 6, loss = 0.62728892
# Iteration 7, loss = 0.62190295
# Iteration 8, loss = 0.61657496
# Iteration 9, loss = 0.61177454
# Iteration 10, loss = 0.60714533
# Iteration 11, loss = 0.60341382
# Iteration 12, loss = 0.60021339
# Iteration 13, loss = 0.59723520
# Iteration 14, loss = 0.59420302
# Iteration 15, loss = 0.59145795
# Iteration 16, loss = 0.58873147
# Iteration 17, loss = 0.58617011
# Iteration 18, loss = 0.58378190
# Iteration 19, loss = 0.58150039
# Iteration 20, loss = 0.57932039
# Iteration 21, loss = 0.57706608
# Iteration 22, loss = 0.57489250
# Iteration 23, loss = 0.57285697
# Iteration 24, loss = 0.57101865
# Iteration 25, loss = 0.56918740
# Iteration 26, loss = 0.56773721
# Iteration 27, loss = 0.56629734
# Iteration 28, loss = 0.56514867
# Iteration 29, loss = 0.56381427
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_16 = MLPClassifier(hidden_layer_sizes= np.array([82, 60, 55]), solver='sgd', verbose=True, max_iter = 500)
m_16.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_16.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_16.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.67407956
# Iteration 2, loss = 0.64775118
# Iteration 3, loss = 0.63935979
# Iteration 4, loss = 0.63374679
# Iteration 5, loss = 0.62922953
# Iteration 6, loss = 0.62500454
# Iteration 7, loss = 0.62038913
# Iteration 8, loss = 0.61477936
# Iteration 9, loss = 0.60826336
# Iteration 10, loss = 0.60221366
# Iteration 11, loss = 0.59710216
# Iteration 12, loss = 0.59342960
# Iteration 13, loss = 0.59025423
# Iteration 14, loss = 0.58753901
# Iteration 15, loss = 0.58518279
# Iteration 16, loss = 0.58284268
# Iteration 17, loss = 0.58060104
# Iteration 18, loss = 0.57864185
# Iteration 19, loss = 0.57664794
# Iteration 20, loss = 0.57484101
# Iteration 21, loss = 0.57306561
# Iteration 22, loss = 0.57137054
# Iteration 23, loss = 0.56967518
# Iteration 24, loss = 0.56791958
# Iteration 25, loss = 0.56638651
# Iteration 26, loss = 0.56491241
# Iteration 27, loss = 0.56325284
# Iteration 28, loss = 0.56207427
# Iteration 29, loss = 0.56062219
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_17 = MLPClassifier(hidden_layer_sizes= np.array([30, 27, 13]), verbose=True, max_iter = 500)
m_17.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_17.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_17.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.62879396
# Iteration 2, loss = 0.59312644
# Iteration 3, loss = 0.58233079
# Iteration 4, loss = 0.57577147
# Iteration 5, loss = 0.57061692
# Iteration 6, loss = 0.56598209
# Iteration 7, loss = 0.56157223
# Iteration 8, loss = 0.55788962
# Iteration 9, loss = 0.55455884
# Iteration 10, loss = 0.55161507
# Iteration 11, loss = 0.54879265
# Iteration 12, loss = 0.54579844
# Iteration 13, loss = 0.54328667
# Iteration 14, loss = 0.54081456
# Iteration 15, loss = 0.53802868
# Iteration 16, loss = 0.53626621
# Iteration 17, loss = 0.53424593
# Iteration 18, loss = 0.53291699
# Iteration 19, loss = 0.53127824
# Iteration 20, loss = 0.53033867
# Iteration 21, loss = 0.52920499
# Iteration 22, loss = 0.52864087
# Iteration 23, loss = 0.52747353
# Iteration 24, loss = 0.52689116
# Iteration 25, loss = 0.52638656
# Iteration 26, loss = 0.52580146
# Iteration 27, loss = 0.52523756
# Iteration 28, loss = 0.52479400
# Iteration 29, loss = 0.52459117
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_18 = MLPClassifier(hidden_layer_sizes= np.array([64, 32, 16]), verbose=True, max_iter = 500)
m_18.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_18.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_18.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.61995974
# Iteration 2, loss = 0.58572260
# Iteration 3, loss = 0.57271800
# Iteration 4, loss = 0.56385472
# Iteration 5, loss = 0.55604786
# Iteration 6, loss = 0.54953495
# Iteration 7, loss = 0.54412586
# Iteration 8, loss = 0.53971298
# Iteration 9, loss = 0.53586925
# Iteration 10, loss = 0.53281172
# Iteration 11, loss = 0.52999097
# Iteration 12, loss = 0.52689740
# Iteration 13, loss = 0.52474342
# Iteration 14, loss = 0.52249080
# Iteration 15, loss = 0.52056875
# Iteration 16, loss = 0.51905033
# Iteration 17, loss = 0.51782506
# Iteration 18, loss = 0.51664879
# Iteration 19, loss = 0.51519630
# Iteration 20, loss = 0.51445180
# Iteration 21, loss = 0.51337320
# Iteration 22, loss = 0.51259314
# Iteration 23, loss = 0.51193669
# Iteration 24, loss = 0.51104688
# Iteration 25, loss = 0.51021178
# Iteration 26, loss = 0.51009994
# Iteration 27, loss = 0.50946880
# Iteration 28, loss = 0.50871929
# Iteration 29, loss = 0.50826252
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_19 = MLPClassifier(hidden_layer_sizes= np.array([28, 18, 8]), verbose=True, max_iter = 500)
m_19.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_19.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_19.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.63758737
# Iteration 2, loss = 0.59743990
# Iteration 3, loss = 0.58558395
# Iteration 4, loss = 0.57785913
# Iteration 5, loss = 0.57173505
# Iteration 6, loss = 0.56677537
# Iteration 7, loss = 0.56222561
# Iteration 8, loss = 0.55854889
# Iteration 9, loss = 0.55571904
# Iteration 10, loss = 0.55317199
# Iteration 11, loss = 0.55118436
# Iteration 12, loss = 0.54922902
# Iteration 13, loss = 0.54714463
# Iteration 14, loss = 0.54605379
# Iteration 15, loss = 0.54424975
# Iteration 16, loss = 0.54301988
# Iteration 17, loss = 0.54152773
# Iteration 18, loss = 0.54085122
# Iteration 19, loss = 0.53951539
# Iteration 20, loss = 0.53860234
# Iteration 21, loss = 0.53772396
# Iteration 22, loss = 0.53640036
# Iteration 23, loss = 0.53581285
# Iteration 24, loss = 0.53516709
# Iteration 25, loss = 0.53413793
# Iteration 26, loss = 0.53341936
# Iteration 27, loss = 0.53275282
# Iteration 28, loss = 0.53241979
# Iteration 29, loss = 0.53160312
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_20 = MLPClassifier(hidden_layer_sizes= np.array([99, 41, 13]), verbose=True, max_iter = 500)
m_20.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_20.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_20.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.61462449
# Iteration 2, loss = 0.58219121
# Iteration 3, loss = 0.56881285
# Iteration 4, loss = 0.55874166
# Iteration 5, loss = 0.55160371
# Iteration 6, loss = 0.54634869
# Iteration 7, loss = 0.54158632
# Iteration 8, loss = 0.53769611
# Iteration 9, loss = 0.53378626
# Iteration 10, loss = 0.53045546
# Iteration 11, loss = 0.52720881
# Iteration 12, loss = 0.52416791
# Iteration 13, loss = 0.52172638
# Iteration 14, loss = 0.51934805
# Iteration 15, loss = 0.51708012
# Iteration 16, loss = 0.51622047
# Iteration 17, loss = 0.51399747
# Iteration 18, loss = 0.51235624
# Iteration 19, loss = 0.51174276
# Iteration 20, loss = 0.51020937
# Iteration 21, loss = 0.50911870
# Iteration 22, loss = 0.50802739
# Iteration 23, loss = 0.50707612
# Iteration 24, loss = 0.50612390
# Iteration 25, loss = 0.50574718
# Iteration 26, loss = 0.50505398
# Iteration 27, loss = 0.50452513
# Iteration 28, loss = 0.50366404
# Iteration 29, loss = 0.50295639
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_21 = MLPClassifier(hidden_layer_sizes= np.array([83, 52, 21]), verbose=True, max_iter = 500)
m_21.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_21.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_21.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.61773145
# Iteration 2, loss = 0.58293925
# Iteration 3, loss = 0.56847951
# Iteration 4, loss = 0.55787339
# Iteration 5, loss = 0.54909070
# Iteration 6, loss = 0.54259516
# Iteration 7, loss = 0.53773289
# Iteration 8, loss = 0.53366103
# Iteration 9, loss = 0.53009418
# Iteration 10, loss = 0.52706277
# Iteration 11, loss = 0.52454553
# Iteration 12, loss = 0.52249809
# Iteration 13, loss = 0.51995778
# Iteration 14, loss = 0.51813787
# Iteration 15, loss = 0.51680295
# Iteration 16, loss = 0.51534460
# Iteration 17, loss = 0.51429017
# Iteration 18, loss = 0.51296891
# Iteration 19, loss = 0.51173170
# Iteration 20, loss = 0.51121676
# Iteration 21, loss = 0.51023682
# Iteration 22, loss = 0.50867827
# Iteration 23, loss = 0.50851091
# Iteration 24, loss = 0.50770518
# Iteration 25, loss = 0.50673239
# Iteration 26, loss = 0.50615644
# Iteration 27, loss = 0.50536009
# Iteration 28, loss = 0.50496840
# Iteration 29, loss = 0.50420262
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_22 = MLPClassifier(hidden_layer_sizes= np.array([100]), verbose=True, max_iter = 500)
m_22.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_22.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_22.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.63536891
# Iteration 2, loss = 0.60432601
# Iteration 3, loss = 0.59224589
# Iteration 4, loss = 0.58556602
# Iteration 5, loss = 0.58025985
# Iteration 6, loss = 0.57554561
# Iteration 7, loss = 0.57169665
# Iteration 8, loss = 0.56786060
# Iteration 9, loss = 0.56465952
# Iteration 10, loss = 0.56167261
# Iteration 11, loss = 0.55938964
# Iteration 12, loss = 0.55714740
# Iteration 13, loss = 0.55466523
# Iteration 14, loss = 0.55213549
# Iteration 15, loss = 0.55036348
# Iteration 16, loss = 0.54843668
# Iteration 17, loss = 0.54674358
# Iteration 18, loss = 0.54562206
# Iteration 19, loss = 0.54441599
# Iteration 20, loss = 0.54315761
# Iteration 21, loss = 0.54197352
# Iteration 22, loss = 0.54112250
# Iteration 23, loss = 0.54006625
# Iteration 24, loss = 0.53923869
# Iteration 25, loss = 0.53922844
# Iteration 26, loss = 0.53779945
# Iteration 27, loss = 0.53710756
# Iteration 28, loss = 0.53672166
# Iteration 29, loss = 0.53638473
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_23 = MLPClassifier(hidden_layer_sizes= np.array([77, 23, 12]), verbose=True, max_iter = 500)
m_23.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_23.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_23.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.61863013
# Iteration 2, loss = 0.58666350
# Iteration 3, loss = 0.57428513
# Iteration 4, loss = 0.56586068
# Iteration 5, loss = 0.55982497
# Iteration 6, loss = 0.55514349
# Iteration 7, loss = 0.55072919
# Iteration 8, loss = 0.54692388
# Iteration 9, loss = 0.54296471
# Iteration 10, loss = 0.53939544
# Iteration 11, loss = 0.53660698
# Iteration 12, loss = 0.53458002
# Iteration 13, loss = 0.53226040
# Iteration 14, loss = 0.53024887
# Iteration 15, loss = 0.52919175
# Iteration 16, loss = 0.52745948
# Iteration 17, loss = 0.52594849
# Iteration 18, loss = 0.52468032
# Iteration 19, loss = 0.52334888
# Iteration 20, loss = 0.52257216
# Iteration 21, loss = 0.52140502
# Iteration 22, loss = 0.52039007
# Iteration 23, loss = 0.51924036
# Iteration 24, loss = 0.51849708
# Iteration 25, loss = 0.51740151
# Iteration 26, loss = 0.51637578
# Iteration 27, loss = 0.51556592
# Iteration 28, loss = 0.51465731
# Iteration 29, loss = 0.51393115
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_24 = MLPClassifier(hidden_layer_sizes= np.array([77, 53, 15, 6]), verbose=True, max_iter = 500)
m_24.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_24.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_24.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.61644596
# Iteration 2, loss = 0.58538869
# Iteration 3, loss = 0.57308455
# Iteration 4, loss = 0.56290264
# Iteration 5, loss = 0.55483027
# Iteration 6, loss = 0.54879625
# Iteration 7, loss = 0.54393814
# Iteration 8, loss = 0.54008120
# Iteration 9, loss = 0.53620336
# Iteration 10, loss = 0.53264584
# Iteration 11, loss = 0.52968635
# Iteration 12, loss = 0.52642078
# Iteration 13, loss = 0.52357229
# Iteration 14, loss = 0.52146286
# Iteration 15, loss = 0.51973151
# Iteration 16, loss = 0.51795128
# Iteration 17, loss = 0.51606779
# Iteration 18, loss = 0.51505186
# Iteration 19, loss = 0.51347665
# Iteration 20, loss = 0.51245095
# Iteration 21, loss = 0.51115917
# Iteration 22, loss = 0.51027113
# Iteration 23, loss = 0.50933763
# Iteration 24, loss = 0.50817754
# Iteration 25, loss = 0.50776656
# Iteration 26, loss = 0.50710476
# Iteration 27, loss = 0.50594081
# Iteration 28, loss = 0.50538556
# Iteration 29, loss = 0.50466404
# ...

# %%
from sklearn.neural_network import MLPClassifier

m_25 = MLPClassifier(hidden_layer_sizes= np.array([78, 64, 48]), verbose=True, max_iter = 500)
m_25.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_25.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_25.score(X_test, y_test))
# Out:
# Iteration 1, loss = 0.61384116
# Iteration 2, loss = 0.58021801
# Iteration 3, loss = 0.56553812
# Iteration 4, loss = 0.55558017
# Iteration 5, loss = 0.54830092
# Iteration 6, loss = 0.54204878
# Iteration 7, loss = 0.53711378
# Iteration 8, loss = 0.53323838
# Iteration 9, loss = 0.52983458
# Iteration 10, loss = 0.52691142
# Iteration 11, loss = 0.52422121
# Iteration 12, loss = 0.52169391
# Iteration 13, loss = 0.51925702
# Iteration 14, loss = 0.51728747
# Iteration 15, loss = 0.51530997
# Iteration 16, loss = 0.51323349
# Iteration 17, loss = 0.51162980
# Iteration 18, loss = 0.50998115
# Iteration 19, loss = 0.50851863
# Iteration 20, loss = 0.50747651
# Iteration 21, loss = 0.50608543
# Iteration 22, loss = 0.50478409
# Iteration 23, loss = 0.50415873
# Iteration 24, loss = 0.50309843
# Iteration 25, loss = 0.50241135
# Iteration 26, loss = 0.50143655
# Iteration 27, loss = 0.50065989
# Iteration 28, loss = 0.50034755
# Iteration 29, loss = 0.49914577
# ...

# %%
m_28 = MLPClassifier(hidden_layer_sizes= np.array([450, 145, 70]), verbose=True, random_state = 0, early_stopping=True, tol=0.001, alpha=0.005)
m_28.fit(X_train, y_train)
print("The training accuracy of the mlp classifier model = ", m_28.score(X_train, y_train))
print("The testing accuracy of the mlp classifier model = ", m_28.score(X_test, y_test))

# %%
"""
Iteration 1, loss = 0.60630307
Validation score: 0.689920
Iteration 2, loss = 0.57135738
Validation score: 0.704189
Iteration 3, loss = 0.55519428
Validation score: 0.712596
Iteration 4, loss = 0.54471501
Validation score: 0.723131
Iteration 5, loss = 0.53627163
Validation score: 0.728284
Iteration 6, loss = 0.52964336
Validation score: 0.729493
Iteration 7, loss = 0.52534434
Validation score: 0.730224
Iteration 8, loss = 0.52084802
Validation score: 0.736357
Iteration 9, loss = 0.51682946
Validation score: 0.740633
Iteration 10, loss = 0.51387795
Validation score: 0.739632
Iteration 11, loss = 0.51131160
Validation score: 0.739110
Iteration 12, loss = 0.50863137
Validation score: 0.735794
Iteration 13, loss = 0.50649252
Validation score: 0.741739
Iteration 14, loss = 0.50451904
Validation score: 0.739882
Iteration 15, loss = 0.50251500
Validation score: 0.718708
Iteration 25, loss = 0.57288447
Validation score: 0.712867
Iteration 26, loss = 0.57198856
Validation score: 0.714912
Iteration 27, loss = 0.57216146
Validation score: 0.703271
Iteration 28, loss = 0.57263447
Validation score: 0.717394
Iteration 29, loss = 0.57219593
Validation score: 0.696616
Iteration 30, loss = 0.57275367
Validation score: 0.717102
Iteration 31, loss = 0.57235400
Validation score: 0.713222
Iteration 32, loss = 0.57168297
Validation score: 0.718583
Iteration 33, loss = 0.57220363
Validation score: 0.713702
Iteration 34, loss = 0.57173620
Validation score: 0.714432
Iteration 35, loss = 0.57180575
Validation score: 0.718729
Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
The training accuracy of the mlp classifier model =  0.7194616955630146
The testing accuracy of the mlp classifier model =  0.7174983311081442
"""

# %% [markdown]
# # 3) Training the data with the xgboost classifier:

# %%
from xgboost import XGBClassifier
model = XGBClassifier(n_estimators = 300, colsample_bytree = 1, learning_rate=0.1, subsample = 0.3, eta = 0.2)
model.fit(X_train, y_train)
print("The accuracy of the xgboost calssifier model = ",model.score(X_test,y_test))
# Out:
# The accuracy of the xgboost calssifier model =  0.7352553404539386

# %% [markdown]
# # 4) Training the data with the Neural Networks from tensorflow

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from tensorflow.keras.layers import Dense
from keras import Sequential
from keras.losses import BinaryCrossentropy
import tensorflow as tf
import numpy  as np

'''Write your code here'''
y = np.array(data.iloc[:,0])
X = np.array(data.iloc[:,1:])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

X_train = X_train.astype(np.float32)
X_train = tf.convert_to_tensor(X_train)
X_test= X_test.astype(np.float32)
X_test = tf.convert_to_tensor(X_test)

tensorflowModel = Sequential([Dense(units= 28, activation='relu' ), Dense(units= 25, activation='relu' ), Dense(units= 20, activation= 'relu'), Dense(units= 18, activation= 'relu'), Dense(units= 10, activation='relu' ), Dense(units= 11, activation= 'relu' ), Dense(units= 8, activation= 'relu' ), Dense(units= 7, activation= 'relu' ),  Dense(units= 5, activation= 'relu' ), Dense(units= 3, activation= 'relu' ), Dense(units= 1, activation= 'sigmoid' )])

tensorflowModel.compile(loss = BinaryCrossentropy(), optimizer ='adam', metrics ='accuracy')

tensorflowModel.fit(X_train, y_train)
loss, train_accuracy = tensorflowModel.evaluate(X_train, y_train)
loss1, test_accuracy = tensorflowModel.evaluate(X_test, y_test)
print(train_accuracy)
print(test_accuracy)
# Out:
# ...
# 3745/3745 [==============================] - 8s 2ms/step - loss: 0.5980 - accuracy: 0.6785
# 0.6784797310829163
# 0.6785046458244324

# %%
from tensorflow.keras.layers import Dense
from keras import Sequential
from keras.losses import BinaryCrossentropy
import tensorflow as tf
import numpy  as np
from tensorflow.keras import regularizers
y = np.array(data.iloc[:,0])
X = np.array(data.iloc[:,1:])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

X_train = X_train.astype(np.float32)
X_train = tf.convert_to_tensor(X_train)
X_test= X_test.astype(np.float32)
X_test = tf.convert_to_tensor(X_test)

# %%
tensorflowModel = Sequential([Dense(units= 530, activation='relu', kernel_regularizer = regularizers.l2(0.0001)), Dense(units= 125, activation='relu' ), Dense(units= 1, activation= 'sigmoid' )])

tensorflowModel.compile(loss = BinaryCrossentropy(), optimizer ='adam', metrics ='accuracy')

tensorflowModel.fit(X_train, y_train, batch_size = 50, epochs = 10)
loss, train_accuracy = tensorflowModel.evaluate(X_train, y_train)
loss1, test_accuracy = tensorflowModel.evaluate(X_test, y_test)
print(train_accuracy)
print(test_accuracy)
# Out:
# Epoch 1/10
# 9588/9588 [==============================] - 62s 6ms/step - loss: 0.6082 - accuracy: 0.6692
# Epoch 2/10
# 9588/9588 [==============================] - 59s 6ms/step - loss: 0.5775 - accuracy: 0.6995
# Epoch 3/10
# 9588/9588 [==============================] - 59s 6ms/step - loss: 0.5641 - accuracy: 0.7111
# Epoch 4/10
# 9588/9588 [==============================] - 60s 6ms/step - loss: 0.5557 - accuracy: 0.7179
# Epoch 5/10
# 9588/9588 [==============================] - 63s 7ms/step - loss: 0.5492 - accuracy: 0.7231
# Epoch 6/10
# 9588/9588 [==============================] - 62s 6ms/step - loss: 0.5444 - accuracy: 0.7275
# Epoch 7/10
# 9588/9588 [==============================] - 58s 6ms/step - loss: 0.5405 - accuracy: 0.7300
# Epoch 8/10
# 9588/9588 [==============================] - 58s 6ms/step - loss: 0.5382 - accuracy: 0.7318
# Epoch 9/10
# 9588/9588 [==============================] - 61s 6ms/step - loss: 0.5360 - accuracy: 0.7334
# Epoch 10/10
# ...

# %%
tensorflowModel_1 = Sequential([Dense(units= 530, activation='relu', kernel_regularizer = regularizers.l2(0.0001)), Dense(units= 205, activation='relu' ), Dense(units= 1, activation= 'sigmoid' )])

tensorflowModel_1.compile(loss = BinaryCrossentropy(), optimizer ='adam', metrics ='accuracy')

tensorflowModel_1.fit(X_train, y_train, batch_size = 50, epochs = 10)
loss, train_accuracy = tensorflowModel_1.evaluate(X_train, y_train)
loss1, test_accuracy = tensorflowModel_1.evaluate(X_test, y_test)
print(train_accuracy)
print(test_accuracy)
# Out:
# Epoch 1/10
# 9588/9588 [==============================] - 84s 9ms/step - loss: 0.6070 - accuracy: 0.6702
# Epoch 2/10
# 9588/9588 [==============================] - 78s 8ms/step - loss: 0.5746 - accuracy: 0.7021
# Epoch 3/10
# 9588/9588 [==============================] - 76s 8ms/step - loss: 0.5616 - accuracy: 0.7128
# Epoch 4/10
# 9588/9588 [==============================] - 78s 8ms/step - loss: 0.5536 - accuracy: 0.7197
# Epoch 5/10
# 9588/9588 [==============================] - 78s 8ms/step - loss: 0.5464 - accuracy: 0.7255
# Epoch 6/10
# 9588/9588 [==============================] - 78s 8ms/step - loss: 0.5413 - accuracy: 0.7291
# Epoch 7/10
# 9588/9588 [==============================] - 80s 8ms/step - loss: 0.5375 - accuracy: 0.7321
# Epoch 8/10
# 9588/9588 [==============================] - 81s 8ms/step - loss: 0.5345 - accuracy: 0.7337
# Epoch 9/10
# 9588/9588 [==============================] - 81s 8ms/step - loss: 0.5317 - accuracy: 0.7362
# Epoch 10/10
# ...
